# %%
import numpy as np
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.load_data_gait import *
from src.plot_data_gait import *

# %%
base_path = '../datasets/GAIT_signals/dataset/data'

# %%
X, y, subjects = load_dataset_gait(base_path)

# %%
print(X.shape)
# Out:
# (158152, 100, 37)

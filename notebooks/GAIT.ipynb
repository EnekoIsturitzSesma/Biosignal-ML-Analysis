# %%
import numpy as np
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.load_data_gait import *
from src.plot_data_gait import *
from src.train_LSTMGait import train_model_cv

# %%
base_path = '../datasets/GAIT_signals/dataset/data'

# %%
X, y, subjects = load_dataset_gait(base_path, window_size=200, stride=50)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
models_per_subject, test_subject_accuracies = train_model_cv(X, y, subjects, epochs=100, lr=0.0003, patience=10)
# Out:
# Early stopping en época 18. Mejor F1: 0.9576
# Fold 1: Val F1 = 0.9576
# Early stopping en época 28. Mejor F1: 0.9805
# Fold 2: Val F1 = 0.9805
# Early stopping en época 28. Mejor F1: 0.9829
# Fold 3: Val F1 = 0.9829
# Early stopping en época 22. Mejor F1: 0.9621
# Fold 4: Val F1 = 0.9621
# Early stopping en época 14. Mejor F1: 0.9469
# Fold 5: Val F1 = 0.9469
# Early stopping en época 24. Mejor F1: 0.9697
# Fold 6: Val F1 = 0.9697
# Early stopping en época 11. Mejor F1: 0.9800
# Fold 7: Val F1 = 0.9800
# Early stopping en época 12. Mejor F1: 0.9583
# Fold 8: Val F1 = 0.9583
# Training:   6%|▌         | 6/100 [00:48<12:33,  8.01s/it, Val F1=0.974, LR=0.000300]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gc 
from sklearn.metrics import f1_score

import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.load_data_gait import *
from src.plot_data_gait import *
from src.train_LSTMGait import train_model_cv, predict_trial

# %%
base_path = '../datasets/GAIT_signals/dataset/data'

# %% [markdown]
# # Only Back Sensor (raw)

# %% [markdown]
# ## Training

# %%
X, y, subjects = load_dataset_gait(base_path, process="raw", sensors=["LB"], window_size=200, stride=50)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
models_per_subject, results_list = train_model_cv(X, y, subjects, model_name="cnnbilstm", epochs=100, lr=0.0003, patience=10, out_dir="../checkpoints/CNNBiLSTM/raw_only_back")
# Out:
# Early stopping in epoch 21. Best F1: 0.8831
# Fold 1 | Subject ACL_1 | Val F1: 0.8831 | Test F1: 0.8882
# Early stopping in epoch 14. Best F1: 0.8801
# Fold 2 | Subject ACL_10 | Val F1: 0.8801 | Test F1: 0.9178
# Early stopping in epoch 15. Best F1: 0.8799
# Fold 3 | Subject ACL_11 | Val F1: 0.8799 | Test F1: 0.9396
# Early stopping in epoch 32. Best F1: 0.8829
# Fold 4 | Subject ACL_2 | Val F1: 0.8829 | Test F1: 0.8968
# Early stopping in epoch 23. Best F1: 0.8822
# Fold 5 | Subject ACL_3 | Val F1: 0.8822 | Test F1: 0.7850
# Early stopping in epoch 24. Best F1: 0.8826
# Fold 6 | Subject ACL_4 | Val F1: 0.8826 | Test F1: 0.8572
# Early stopping in epoch 19. Best F1: 0.8818
# Fold 7 | Subject ACL_5 | Val F1: 0.8818 | Test F1: 0.6635
# Early stopping in epoch 16. Best F1: 0.8746
# Fold 8 | Subject ACL_6 | Val F1: 0.8746 | Test F1: 0.9270
# Early stopping in epoch 24. Best F1: 0.8785
# Fold 9 | Subject ACL_7 | Val F1: 0.8785 | Test F1: 0.8612
# Early stopping in epoch 29. Best F1: 0.8787
# Fold 10 | Subject ACL_8 | Val F1: 0.8787 | Test F1: 0.9065
# Early stopping in epoch 28. Best F1: 0.8743
# Fold 11 | Subject ACL_9 | Val F1: 0.8743 | Test F1: 0.9001
# Early stopping in epoch 21. Best F1: 0.8758
# Fold 12 | Subject CIPN_1 | Val F1: 0.8758 | Test F1: 0.9346
# Early stopping in epoch 24. Best F1: 0.8796
# Fold 13 | Subject CIPN_10 | Val F1: 0.8796 | Test F1: 0.9526
# Early stopping in epoch 18. Best F1: 0.8731
# Fold 14 | Subject CIPN_11 | Val F1: 0.8731 | Test F1: 0.9623
# Early stopping in epoch 29. Best F1: 0.8772
# Fold 15 | Subject CIPN_12 | Val F1: 0.8772 | Test F1: 0.9553
# Early stopping in epoch 27. Best F1: 0.8788
# Fold 16 | Subject CIPN_13 | Val F1: 0.8788 | Test F1: 0.9531
# Early stopping in epoch 17. Best F1: 0.8730
# Fold 17 | Subject CIPN_14 | Val F1: 0.8730 | Test F1: 0.9498
# Early stopping in epoch 21. Best F1: 0.8791
# Fold 18 | Subject CIPN_15 | Val F1: 0.8791 | Test F1: 0.9312
# Early stopping in epoch 41. Best F1: 0.8767
# Fold 19 | Subject CIPN_16 | Val F1: 0.8767 | Test F1: 0.9353
# Early stopping in epoch 35. Best F1: 0.8758
# Fold 20 | Subject CIPN_17 | Val F1: 0.8758 | Test F1: 0.7274
# Early stopping in epoch 33. Best F1: 0.8702
# Fold 21 | Subject CIPN_18 | Val F1: 0.8702 | Test F1: 0.9100
# Early stopping in epoch 19. Best F1: 0.8686
# Fold 22 | Subject CIPN_19 | Val F1: 0.8686 | Test F1: 0.9456
# Early stopping in epoch 14. Best F1: 0.8676
# Fold 23 | Subject CIPN_2 | Val F1: 0.8676 | Test F1: 0.9564
# Early stopping in epoch 19. Best F1: 0.8712
# Fold 24 | Subject CIPN_3 | Val F1: 0.8712 | Test F1: 0.6027
# Early stopping in epoch 29. Best F1: 0.8728
# Fold 25 | Subject CIPN_4 | Val F1: 0.8728 | Test F1: 0.9387
# Early stopping in epoch 29. Best F1: 0.8684
# Fold 26 | Subject CIPN_5 | Val F1: 0.8684 | Test F1: 0.9224
# Early stopping in epoch 42. Best F1: 0.8721
# Fold 27 | Subject CIPN_6 | Val F1: 0.8721 | Test F1: 0.9161
# Early stopping in epoch 28. Best F1: 0.8675
# Fold 28 | Subject CIPN_7 | Val F1: 0.8675 | Test F1: 0.9537
# Early stopping in epoch 19. Best F1: 0.8684
# Fold 29 | Subject CIPN_8 | Val F1: 0.8684 | Test F1: 0.9198
# Early stopping in epoch 38. Best F1: 0.8718
# Fold 30 | Subject CIPN_9 | Val F1: 0.8718 | Test F1: 0.9417
# Early stopping in epoch 32. Best F1: 0.8698
# Fold 31 | Subject CVA_1 | Val F1: 0.8698 | Test F1: 0.8956
# Early stopping in epoch 23. Best F1: 0.8665
# Fold 32 | Subject CVA_10 | Val F1: 0.8665 | Test F1: 0.7819
# Early stopping in epoch 19. Best F1: 0.8711
# Fold 33 | Subject CVA_11 | Val F1: 0.8711 | Test F1: 0.8406
# Early stopping in epoch 55. Best F1: 0.8730
# Fold 34 | Subject CVA_12 | Val F1: 0.8730 | Test F1: 0.8569
# Early stopping in epoch 21. Best F1: 0.8704
# Fold 35 | Subject CVA_13 | Val F1: 0.8704 | Test F1: 0.9038
# Early stopping in epoch 43. Best F1: 0.8720
# Fold 36 | Subject CVA_14 | Val F1: 0.8720 | Test F1: 0.8696
# Early stopping in epoch 19. Best F1: 0.8743
# Fold 37 | Subject CVA_15 | Val F1: 0.8743 | Test F1: 0.9271
# Early stopping in epoch 26. Best F1: 0.8708
# Fold 38 | Subject CVA_16 | Val F1: 0.8708 | Test F1: 0.9186
# Early stopping in epoch 15. Best F1: 0.8686
# Fold 39 | Subject CVA_17 | Val F1: 0.8686 | Test F1: 0.7792
# Early stopping in epoch 30. Best F1: 0.8706
# Fold 40 | Subject CVA_18 | Val F1: 0.8706 | Test F1: 0.7621
# Early stopping in epoch 35. Best F1: 0.8722
# Fold 41 | Subject CVA_19 | Val F1: 0.8722 | Test F1: 0.8770
# Early stopping in epoch 27. Best F1: 0.8651
# Fold 42 | Subject CVA_2 | Val F1: 0.8651 | Test F1: 0.8974
# Early stopping in epoch 16. Best F1: 0.8664
# Fold 43 | Subject CVA_20 | Val F1: 0.8664 | Test F1: 0.5931
# Early stopping in epoch 29. Best F1: 0.8656
# Fold 44 | Subject CVA_21 | Val F1: 0.8656 | Test F1: 0.5368
# Early stopping in epoch 16. Best F1: 0.8663
# Fold 45 | Subject CVA_22 | Val F1: 0.8663 | Test F1: 0.7427
# Early stopping in epoch 24. Best F1: 0.8707
# Fold 46 | Subject CVA_23 | Val F1: 0.8707 | Test F1: 0.9245
# Early stopping in epoch 20. Best F1: 0.8724
# Fold 47 | Subject CVA_24 | Val F1: 0.8724 | Test F1: 0.8943
# Early stopping in epoch 28. Best F1: 0.8728
# Fold 48 | Subject CVA_25 | Val F1: 0.8728 | Test F1: 0.8367
# Early stopping in epoch 31. Best F1: 0.8708
# Fold 49 | Subject CVA_26 | Val F1: 0.8708 | Test F1: 0.9317
# Early stopping in epoch 33. Best F1: 0.8709
# Fold 50 | Subject CVA_27 | Val F1: 0.8709 | Test F1: 0.9065
# Early stopping in epoch 48. Best F1: 0.8705
# Fold 51 | Subject CVA_28 | Val F1: 0.8705 | Test F1: 0.8611
# Early stopping in epoch 25. Best F1: 0.8682
# Fold 52 | Subject CVA_29 | Val F1: 0.8682 | Test F1: 0.9285
# Early stopping in epoch 19. Best F1: 0.8672
# Fold 53 | Subject CVA_3 | Val F1: 0.8672 | Test F1: 0.9108
# Early stopping in epoch 35. Best F1: 0.8701
# Fold 54 | Subject CVA_30 | Val F1: 0.8701 | Test F1: 0.9529
# Early stopping in epoch 20. Best F1: 0.8667
# Fold 55 | Subject CVA_31 | Val F1: 0.8667 | Test F1: 0.9222
# Early stopping in epoch 25. Best F1: 0.8716
# Fold 56 | Subject CVA_32 | Val F1: 0.8716 | Test F1: 0.9189
# Early stopping in epoch 20. Best F1: 0.8756
# Fold 57 | Subject CVA_33 | Val F1: 0.8756 | Test F1: 0.6404
# Early stopping in epoch 30. Best F1: 0.8742
# Fold 58 | Subject CVA_34 | Val F1: 0.8742 | Test F1: 0.9197
# Early stopping in epoch 24. Best F1: 0.8764
# Fold 59 | Subject CVA_35 | Val F1: 0.8764 | Test F1: 0.9382
# Early stopping in epoch 21. Best F1: 0.8787
# Fold 60 | Subject CVA_36 | Val F1: 0.8787 | Test F1: 0.8971
# Early stopping in epoch 21. Best F1: 0.8721
# Fold 61 | Subject CVA_37 | Val F1: 0.8721 | Test F1: 0.8262
# Early stopping in epoch 29. Best F1: 0.8749
# Fold 62 | Subject CVA_38 | Val F1: 0.8749 | Test F1: 0.9355
# Early stopping in epoch 32. Best F1: 0.8748
# Fold 63 | Subject CVA_39 | Val F1: 0.8748 | Test F1: 0.9277
# Early stopping in epoch 23. Best F1: 0.8787
# Fold 64 | Subject CVA_4 | Val F1: 0.8787 | Test F1: 0.8912
# Early stopping in epoch 29. Best F1: 0.8804
# Fold 65 | Subject CVA_40 | Val F1: 0.8804 | Test F1: 0.8922
# Early stopping in epoch 26. Best F1: 0.8806
# Fold 66 | Subject CVA_41 | Val F1: 0.8806 | Test F1: 0.9060
# Fold 139 | Subject HS_5 | Val F1: 0.8832 | Test F1: 0.9535
# Early stopping in epoch 35. Best F1: 0.8798
# Fold 140 | Subject HS_50 | Val F1: 0.8798 | Test F1: 0.9299
# Early stopping in epoch 26. Best F1: 0.8822
# Fold 141 | Subject HS_51 | Val F1: 0.8822 | Test F1: 0.9183
# Early stopping in epoch 21. Best F1: 0.8795
# Fold 142 | Subject HS_52 | Val F1: 0.8795 | Test F1: 0.8217
# Early stopping in epoch 46. Best F1: 0.8834
# Fold 143 | Subject HS_53 | Val F1: 0.8834 | Test F1: 0.7311
# Early stopping in epoch 21. Best F1: 0.8822
# Fold 144 | Subject HS_54 | Val F1: 0.8822 | Test F1: 0.9073
# Early stopping in epoch 39. Best F1: 0.8802
# Fold 145 | Subject HS_55 | Val F1: 0.8802 | Test F1: 0.9085
# Early stopping in epoch 27. Best F1: 0.8841
# Fold 146 | Subject HS_56 | Val F1: 0.8841 | Test F1: 0.8944
# Early stopping in epoch 21. Best F1: 0.8822
# Fold 147 | Subject HS_57 | Val F1: 0.8822 | Test F1: 0.9184
# Early stopping in epoch 26. Best F1: 0.8812
# Fold 148 | Subject HS_58 | Val F1: 0.8812 | Test F1: 0.8057
# Early stopping in epoch 21. Best F1: 0.8832
# Fold 149 | Subject HS_59 | Val F1: 0.8832 | Test F1: 0.9384
# Early stopping in epoch 34. Best F1: 0.8853
# Fold 150 | Subject HS_6 | Val F1: 0.8853 | Test F1: 0.8716
# Early stopping in epoch 28. Best F1: 0.8809
# Fold 151 | Subject HS_60 | Val F1: 0.8809 | Test F1: 0.8427
# Early stopping in epoch 25. Best F1: 0.8812
# Fold 152 | Subject HS_61 | Val F1: 0.8812 | Test F1: 0.7228
# Early stopping in epoch 29. Best F1: 0.8809
# Fold 153 | Subject HS_62 | Val F1: 0.8809 | Test F1: 0.8848
# Early stopping in epoch 33. Best F1: 0.8842
# Fold 154 | Subject HS_63 | Val F1: 0.8842 | Test F1: 0.7843
# Early stopping in epoch 17. Best F1: 0.8747
# Fold 155 | Subject HS_64 | Val F1: 0.8747 | Test F1: 0.9501
# Early stopping in epoch 51. Best F1: 0.8870
# Fold 156 | Subject HS_65 | Val F1: 0.8870 | Test F1: 0.7746
# Early stopping in epoch 29. Best F1: 0.8810
# Fold 157 | Subject HS_66 | Val F1: 0.8810 | Test F1: 0.7608
# Early stopping in epoch 27. Best F1: 0.8845
# Fold 158 | Subject HS_67 | Val F1: 0.8845 | Test F1: 0.8966
# Early stopping in epoch 31. Best F1: 0.8858
# Fold 159 | Subject HS_68 | Val F1: 0.8858 | Test F1: 0.9272
# Early stopping in epoch 33. Best F1: 0.8847
# Fold 160 | Subject HS_69 | Val F1: 0.8847 | Test F1: 0.8448
# Early stopping in epoch 34. Best F1: 0.8813
# Fold 161 | Subject HS_7 | Val F1: 0.8813 | Test F1: 0.8173
# Early stopping in epoch 36. Best F1: 0.8817
# Fold 162 | Subject HS_70 | Val F1: 0.8817 | Test F1: 0.8096
# Early stopping in epoch 39. Best F1: 0.8841
# Fold 187 | Subject PD_10 | Val F1: 0.8883 | Test F1: 0.9163
# Early stopping in epoch 26. Best F1: 0.8912
# Fold 188 | Subject PD_11 | Val F1: 0.8912 | Test F1: 0.9392
# Early stopping in epoch 28. Best F1: 0.8889
# Fold 189 | Subject PD_12 | Val F1: 0.8889 | Test F1: 0.9288
# Early stopping in epoch 36. Best F1: 0.8908
# Fold 190 | Subject PD_13 | Val F1: 0.8908 | Test F1: 0.8934
# Early stopping in epoch 42. Best F1: 0.8905
# Fold 191 | Subject PD_14 | Val F1: 0.8905 | Test F1: 0.9331
# Early stopping in epoch 29. Best F1: 0.8908
# Fold 192 | Subject PD_15 | Val F1: 0.8908 | Test F1: 0.8341
# Early stopping in epoch 40. Best F1: 0.8886
# Fold 193 | Subject PD_16 | Val F1: 0.8886 | Test F1: 0.9429
# Early stopping in epoch 34. Best F1: 0.8899
# Fold 194 | Subject PD_17 | Val F1: 0.8899 | Test F1: 0.8913
# Early stopping in epoch 30. Best F1: 0.8854
# Fold 195 | Subject PD_18 | Val F1: 0.8854 | Test F1: 0.9039
# Early stopping in epoch 27. Best F1: 0.8868
# Fold 196 | Subject PD_19 | Val F1: 0.8868 | Test F1: 0.9425
# Early stopping in epoch 24. Best F1: 0.8901
# Fold 197 | Subject PD_2 | Val F1: 0.8901 | Test F1: 0.8843
# Early stopping in epoch 29. Best F1: 0.8888
# Fold 198 | Subject PD_20 | Val F1: 0.8888 | Test F1: 0.7960
# Early stopping in epoch 22. Best F1: 0.8909
# Fold 199 | Subject PD_21 | Val F1: 0.8909 | Test F1: 0.9013
# Early stopping in epoch 49. Best F1: 0.8891
# Fold 200 | Subject PD_22 | Val F1: 0.8891 | Test F1: 0.8791
# Early stopping in epoch 30. Best F1: 0.8855
# Fold 201 | Subject PD_23 | Val F1: 0.8855 | Test F1: 0.4065
# Early stopping in epoch 40. Best F1: 0.8743
# Fold 202 | Subject PD_24 | Val F1: 0.8743 | Test F1: 0.9322
# Early stopping in epoch 28. Best F1: 0.8831
# Fold 203 | Subject PD_3 | Val F1: 0.8831 | Test F1: 0.8950
# Early stopping in epoch 23. Best F1: 0.8723
# Fold 204 | Subject PD_4 | Val F1: 0.8723 | Test F1: 0.9281
# Early stopping in epoch 29. Best F1: 0.8738
# Fold 205 | Subject PD_5 | Val F1: 0.8738 | Test F1: 0.9101
# Early stopping in epoch 45. Best F1: 0.8764
# Fold 206 | Subject PD_6 | Val F1: 0.8764 | Test F1: 0.4581
# Early stopping in epoch 41. Best F1: 0.8660
# Fold 207 | Subject PD_7 | Val F1: 0.8660 | Test F1: 0.9297
# Early stopping in epoch 34. Best F1: 0.8605
# Fold 208 | Subject PD_8 | Val F1: 0.8605 | Test F1: 0.9335
# Early stopping in epoch 39. Best F1: 0.8641
# Fold 209 | Subject PD_9 | Val F1: 0.8641 | Test F1: 0.9389
# Early stopping in epoch 24. Best F1: 0.8594
# Fold 210 | Subject RIL_1 | Val F1: 0.8594 | Test F1: 0.9321
# Early stopping in epoch 43. Best F1: 0.8694
# Fold 211 | Subject RIL_10 | Val F1: 0.8694 | Test F1: 0.9205
# Early stopping in epoch 23. Best F1: 0.8597
# Fold 212 | Subject RIL_11 | Val F1: 0.8597 | Test F1: 0.9466
# Early stopping in epoch 25. Best F1: 0.8583
# Fold 213 | Subject RIL_12 | Val F1: 0.8583 | Test F1: 0.6203
# Early stopping in epoch 16. Best F1: 0.8385
# Fold 214 | Subject RIL_13 | Val F1: 0.8385 | Test F1: 0.9361
# Early stopping in epoch 19. Best F1: 0.8448
# Fold 215 | Subject RIL_14 | Val F1: 0.8448 | Test F1: 0.9450
# Early stopping in epoch 23. Best F1: 0.8425
# Fold 216 | Subject RIL_15 | Val F1: 0.8425 | Test F1: 0.8022
# Early stopping in epoch 26. Best F1: 0.8389
# Fold 217 | Subject RIL_16 | Val F1: 0.8389 | Test F1: 0.9110
# Early stopping in epoch 28. Best F1: 0.8396
# Fold 218 | Subject RIL_17 | Val F1: 0.8396 | Test F1: 0.2900
# Early stopping in epoch 20. Best F1: 0.8424
# Fold 219 | Subject RIL_18 | Val F1: 0.8424 | Test F1: 0.9520
# Early stopping in epoch 32. Best F1: 0.8464
# Fold 220 | Subject RIL_19 | Val F1: 0.8464 | Test F1: 0.9226
# Early stopping in epoch 39. Best F1: 0.8469
# Fold 221 | Subject RIL_2 | Val F1: 0.8469 | Test F1: 0.7434
# Early stopping in epoch 31. Best F1: 0.8463
# Fold 222 | Subject RIL_20 | Val F1: 0.8463 | Test F1: 0.9600
# Early stopping in epoch 30. Best F1: 0.8409
# Fold 223 | Subject RIL_21 | Val F1: 0.8409 | Test F1: 0.2855
# Early stopping in epoch 36. Best F1: 0.8429
# Fold 224 | Subject RIL_22 | Val F1: 0.8429 | Test F1: 0.4358
# Early stopping in epoch 20. Best F1: 0.8403
# Fold 225 | Subject RIL_23 | Val F1: 0.8403 | Test F1: 0.9075
# Early stopping in epoch 26. Best F1: 0.8383
# Fold 226 | Subject RIL_24 | Val F1: 0.8383 | Test F1: 0.7990
# Early stopping in epoch 35. Best F1: 0.8436
# Fold 227 | Subject RIL_25 | Val F1: 0.8436 | Test F1: 0.6290
# Early stopping in epoch 43. Best F1: 0.8441
# Fold 228 | Subject RIL_26 | Val F1: 0.8441 | Test F1: 0.5763
# Early stopping in epoch 33. Best F1: 0.8264
# Fold 229 | Subject RIL_27 | Val F1: 0.8264 | Test F1: 0.9021
# Early stopping in epoch 33. Best F1: 0.8328
# Fold 230 | Subject RIL_28 | Val F1: 0.8328 | Test F1: 0.8902
# Early stopping in epoch 22. Best F1: 0.8319
# Fold 231 | Subject RIL_29 | Val F1: 0.8319 | Test F1: 0.8470
# Early stopping in epoch 17. Best F1: 0.8331
# Fold 232 | Subject RIL_3 | Val F1: 0.8331 | Test F1: 0.8897
# Early stopping in epoch 29. Best F1: 0.8354
# Fold 233 | Subject RIL_30 | Val F1: 0.8354 | Test F1: 0.9438
# Early stopping in epoch 18. Best F1: 0.8282
# Fold 234 | Subject RIL_31 | Val F1: 0.8282 | Test F1: 0.8071
# Early stopping in epoch 35. Best F1: 0.8363
# Fold 235 | Subject RIL_32 | Val F1: 0.8363 | Test F1: 0.7105
# Early stopping in epoch 24. Best F1: 0.8324
# Fold 236 | Subject RIL_33 | Val F1: 0.8324 | Test F1: 0.9268
# Early stopping in epoch 23. Best F1: 0.8283
# Fold 237 | Subject RIL_34 | Val F1: 0.8283 | Test F1: 0.9483
# Early stopping in epoch 31. Best F1: 0.8363
# Fold 238 | Subject RIL_35 | Val F1: 0.8363 | Test F1: 0.9190
# Early stopping in epoch 29. Best F1: 0.8373
# Fold 239 | Subject RIL_36 | Val F1: 0.8373 | Test F1: 0.8922
# Early stopping in epoch 21. Best F1: 0.8320
# Fold 240 | Subject RIL_37 | Val F1: 0.8320 | Test F1: 0.8025
# Early stopping in epoch 24. Best F1: 0.8342
# Fold 241 | Subject RIL_38 | Val F1: 0.8342 | Test F1: 0.8908
# Early stopping in epoch 21. Best F1: 0.8335
# Fold 242 | Subject RIL_39 | Val F1: 0.8335 | Test F1: 0.8358
# Early stopping in epoch 37. Best F1: 0.8373
# Fold 243 | Subject RIL_4 | Val F1: 0.8373 | Test F1: 0.7756
# Early stopping in epoch 20. Best F1: 0.8330
# Fold 244 | Subject RIL_40 | Val F1: 0.8330 | Test F1: 0.9286
# Early stopping in epoch 20. Best F1: 0.8347
# Fold 245 | Subject RIL_41 | Val F1: 0.8347 | Test F1: 0.9063
# Early stopping in epoch 16. Best F1: 0.8352
# Fold 246 | Subject RIL_42 | Val F1: 0.8352 | Test F1: 0.4264
# Early stopping in epoch 16. Best F1: 0.8342
# Fold 247 | Subject RIL_43 | Val F1: 0.8342 | Test F1: 0.8176
# Early stopping in epoch 30. Best F1: 0.8372
# Fold 248 | Subject RIL_44 | Val F1: 0.8372 | Test F1: 0.9271
# Early stopping in epoch 21. Best F1: 0.8387
# Fold 249 | Subject RIL_45 | Val F1: 0.8387 | Test F1: 0.9289
# Early stopping in epoch 35. Best F1: 0.8390
# Fold 250 | Subject RIL_46 | Val F1: 0.8390 | Test F1: 0.8337
# Early stopping in epoch 30. Best F1: 0.8353
# Fold 251 | Subject RIL_47 | Val F1: 0.8353 | Test F1: 0.9279
# Early stopping in epoch 36. Best F1: 0.8371
# Fold 252 | Subject RIL_48 | Val F1: 0.8371 | Test F1: 0.9178
# Early stopping in epoch 26. Best F1: 0.8272
# Fold 253 | Subject RIL_49 | Val F1: 0.8272 | Test F1: 0.5162
# Early stopping in epoch 26. Best F1: 0.8368
# Fold 254 | Subject RIL_5 | Val F1: 0.8368 | Test F1: 0.9378
# Early stopping in epoch 27. Best F1: 0.8387
# Fold 255 | Subject RIL_50 | Val F1: 0.8387 | Test F1: 0.8160
# Early stopping in epoch 23. Best F1: 0.8313
# Fold 256 | Subject RIL_51 | Val F1: 0.8313 | Test F1: 0.9226
# Early stopping in epoch 27. Best F1: 0.8279
# Fold 257 | Subject RIL_6 | Val F1: 0.8279 | Test F1: 0.9490
# Early stopping in epoch 17. Best F1: 0.8270
# Fold 258 | Subject RIL_7 | Val F1: 0.8270 | Test F1: 0.8867
# Early stopping in epoch 31. Best F1: 0.8356
# Fold 259 | Subject RIL_8 | Val F1: 0.8356 | Test F1: 0.9456
# Early stopping in epoch 32. Best F1: 0.8368
# Fold 260 | Subject RIL_9 | Val F1: 0.8368 | Test F1: 0.7727
#
# Mean Test F1: 0.8531 ± 0.1222

# %% [markdown]
# ## Analysis

# %%
f1_scores = np.vstack((np.unique(subjects), results_list))
f1_scores = pd.DataFrame(f1_scores.T, columns=['patient', 'score'])
f1_scores.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f1_scores = np.vstack((np.unique(subjects), results_list))
#       2 f1_scores = pd.DataFrame(f1_scores.T, columns=['patient', 'score'])
#       3 f1_scores.head()
#
# NameError: name 'subjects' is not defined

# %%
f1_scores.to_csv("../results/results_raw_LB_gait_cnnbilstm.csv", index=False)

# %%
results_raw_LB = pd.read_csv("../results/results_raw_LB_gait_cnnbilstm.csv")

# %%
print(f'Mean f1-score: {np.mean(results_raw_LB["score"])}')
print(f'Standard deviation: {np.std(results_raw_LB["score"])}')
# Out:
# Mean f1-score: 0.8531330684044285
# Standard deviation: 0.12216951874533036

# %%
healthy = 'lightgreen'
ortho = 'lightcoral'
neuro = 'lightblue'

cohorts = {
    'HS': (("healthy", healthy), []),
    'ACL': (("ortho", ortho), []),
    'HOA': (("ortho", ortho), []),
    'KOA': (("ortho", ortho), []),
    'CIPN': (("neuro", neuro), []),
    'CVA': (("neuro", neuro), []),
    'PD': (("neuro", neuro), []),
    'RIL': (("neuro", neuro), [])}


for cohort in cohorts.keys():
    for patient_name in results_raw_LB['patient']:
        if cohort in patient_name:
            score = results_raw_LB.loc[results_raw_LB['patient'] == patient_name, 'score'].values[0]
            cohorts[cohort][1].append(score)

mean = np.mean(results_raw_LB["score"])

plt.figure(figsize=(12,8))

for cohort in cohorts.keys():
    bar = plt.bar(
        cohort,
        np.mean(cohorts[cohort][1]),
        yerr=np.std(cohorts[cohort][1]),
        capsize=5,
        label=cohorts[cohort][0][0],
        color=cohorts[cohort][0][1])

    plt.bar_label(bar, fmt='%.4f')

plt.axhline(y=mean, color='black', linestyle='--', label=f'Mean = {mean:.4f}')

plt.ylim(0.4, 1.05)

plt.legend()
plt.show()

# %% [markdown]
# # Prediction Visualization

# %%
best_subj_idx = np.argmax(results_raw_LB['score'])
best_subj = results_raw_LB.iloc[best_subj_idx]['patient'] 
print('Subject with the best score:')
print(results_raw_LB.iloc[best_subj_idx])
print('')

worst_subj_idx = np.argmin(results_raw_LB['score'])
worst_subj = results_raw_LB.iloc[worst_subj_idx]['patient'] 
print('Subject with the worst score:')
print(results_raw_LB.iloc[worst_subj_idx])
print('')
# Out:
# Subject with the best score:
# patient     CIPN_11
# score      0.962338
# Name: 13, dtype: object
#
# Subject with the worst score:
# patient      RIL_21
# score      0.285514
# Name: 222, dtype: object

# %%
best_subj_trial = f"{best_subj}_1"  # Obtain first trial of the best classified subject 
worst_subj_trial = f"{worst_subj}_1"  # Obtain first trial of the worst classified subject 

print(best_subj_trial)
print(worst_subj_trial)
# Out:
# CIPN_11_1
# RIL_21_1

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = best_subj_trial,   
    subject     = best_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"], 
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.9748

# %%
best_subj_meta = load_trial(base_path, best_subj_trial)
best_subj_meta = best_subj_meta["metadata"] 
best_subj_cohort = best_subj_meta["pathologyKey"] 
best_subj_group = best_subj_meta["group"] 

worst_subj_meta = load_trial(base_path, worst_subj_trial)
worst_subj_meta = worst_subj_meta["metadata"] 
worst_subj_cohort = worst_subj_meta["pathologyKey"] 
worst_subj_group = worst_subj_meta["group"]

# %%
path = base_path + f"/{best_subj_group}/{best_subj_cohort}/{best_subj}/{best_subj_trial}"

plot_gait_detection(
    y_true, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')
# Out:
# Index(['PacketCounter', 'Acc_X', 'Acc_Y', 'Acc_Z', 'Gyr_X', 'Gyr_Y', 'Gyr_Z',
#        'Mag_X', 'Mag_Y', 'Mag_Z'],
#       dtype='object')
# Acc_Z    1.383688
# dtype: float64 Acc_Z    0.949957
# dtype: float64
# Index(['PacketCounter', 'Acc_X', 'Acc_Y', 'Acc_Z', 'Gyr_X', 'Gyr_Y', 'Gyr_Z',
#        'Mag_X', 'Mag_Y', 'Mag_Z'],
#       dtype='object')
# Acc_Z    1.383688
# dtype: float64 Acc_Z    0.949957
# dtype: float64

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = worst_subj_trial,   
    subject     = worst_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"],
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.2796

# %%
path = base_path + f"/{worst_subj_group}/{worst_subj_cohort}/{worst_subj}/{worst_subj_trial}"

plot_gait_detection(
    y_true, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')
# Out:
# Index(['PacketCounter', 'Acc_X', 'Acc_Y', 'Acc_Z', 'Gyr_X', 'Gyr_Y', 'Gyr_Z',
#        'Mag_X', 'Mag_Y', 'Mag_Z'],
#       dtype='object')
# Acc_Z   -2.723955
# dtype: float64 Acc_Z    1.029978
# dtype: float64
# Index(['PacketCounter', 'Acc_X', 'Acc_Y', 'Acc_Z', 'Gyr_X', 'Gyr_Y', 'Gyr_Z',
#        'Mag_X', 'Mag_Y', 'Mag_Z'],
#       dtype='object')
# Acc_Z   -2.723955
# dtype: float64 Acc_Z    1.029978
# dtype: float64

# %% [markdown]
# It is clear that there is a big difference in the mean value of the best subject's trial and the worst one's. This might be the reason why this trial is predicted so poorly. In order to try to solve this we're going to apply a different normalization, instead of a global normalization (using just the trining data to avoid data leakage), we're going to normalize per window, that way discrepancies between the mean value for different subjects gets minimized.

# %% [markdown]
# # Only Back Sensor (raw + normalization per window)

# %% [markdown]
# ## Training

# %%
X, y, subjects = load_dataset_gait(base_path, process="raw", sensors=["LB"], window_size=200, stride=50)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
models_per_subject, results_list = train_model_cv(X, y, subjects, model_name="cnnbilstm", norm="window", epochs=100, lr=0.0003, patience=10, out_dir="../checkpoints/CNNBiLSTM/raw_only_back_window_norm")
# Out:
# Early stopping in epoch 27. Best F1: 0.8827
# Fold 1 | Subject ACL_1 | Val F1: 0.8827 | Test F1: 0.8862
# Early stopping in epoch 18. Best F1: 0.8858
# Fold 2 | Subject ACL_10 | Val F1: 0.8858 | Test F1: 0.8451
# Early stopping in epoch 35. Best F1: 0.8832
# Fold 3 | Subject ACL_11 | Val F1: 0.8832 | Test F1: 0.9099
# Early stopping in epoch 38. Best F1: 0.8851
# Fold 4 | Subject ACL_2 | Val F1: 0.8851 | Test F1: 0.8704
# Early stopping in epoch 37. Best F1: 0.8852
# Fold 5 | Subject ACL_3 | Val F1: 0.8852 | Test F1: 0.9225
# Early stopping in epoch 18. Best F1: 0.8820
# Fold 6 | Subject ACL_4 | Val F1: 0.8820 | Test F1: 0.8746
# Early stopping in epoch 19. Best F1: 0.8854
# Fold 7 | Subject ACL_5 | Val F1: 0.8854 | Test F1: 0.6887
# Early stopping in epoch 21. Best F1: 0.8808
# Fold 8 | Subject ACL_6 | Val F1: 0.8808 | Test F1: 0.8724
# Early stopping in epoch 23. Best F1: 0.8829
# Fold 9 | Subject ACL_7 | Val F1: 0.8829 | Test F1: 0.8438
# Early stopping in epoch 19. Best F1: 0.8774
# Fold 10 | Subject ACL_8 | Val F1: 0.8774 | Test F1: 0.9411
# Early stopping in epoch 29. Best F1: 0.8807
# Fold 11 | Subject ACL_9 | Val F1: 0.8807 | Test F1: 0.9163
# Early stopping in epoch 31. Best F1: 0.8799
# Fold 12 | Subject CIPN_1 | Val F1: 0.8799 | Test F1: 0.9488
# Early stopping in epoch 19. Best F1: 0.8785
# Fold 13 | Subject CIPN_10 | Val F1: 0.8785 | Test F1: 0.9572
# Early stopping in epoch 28. Best F1: 0.8810
# Fold 14 | Subject CIPN_11 | Val F1: 0.8810 | Test F1: 0.9529
# Early stopping in epoch 22. Best F1: 0.8847
# Fold 15 | Subject CIPN_12 | Val F1: 0.8847 | Test F1: 0.9584
# Early stopping in epoch 20. Best F1: 0.8812
# Fold 16 | Subject CIPN_13 | Val F1: 0.8812 | Test F1: 0.9388
# Early stopping in epoch 27. Best F1: 0.8865
# Fold 17 | Subject CIPN_14 | Val F1: 0.8865 | Test F1: 0.9524
# Early stopping in epoch 37. Best F1: 0.8826
# Early stopping in epoch 37. Best F1: 0.8756
# Fold 211 | Subject RIL_10 | Val F1: 0.8756 | Test F1: 0.9401
# Early stopping in epoch 20. Best F1: 0.8744
# Fold 212 | Subject RIL_11 | Val F1: 0.8744 | Test F1: 0.9593
# Early stopping in epoch 29. Best F1: 0.8716
# Fold 213 | Subject RIL_12 | Val F1: 0.8716 | Test F1: 0.6653
# Early stopping in epoch 34. Best F1: 0.8544
# Fold 214 | Subject RIL_13 | Val F1: 0.8544 | Test F1: 0.9371
# Early stopping in epoch 25. Best F1: 0.8575
# Fold 215 | Subject RIL_14 | Val F1: 0.8575 | Test F1: 0.9438
# Early stopping in epoch 23. Best F1: 0.8532
# Fold 216 | Subject RIL_15 | Val F1: 0.8532 | Test F1: 0.7587
# Early stopping in epoch 25. Best F1: 0.8541
# Fold 217 | Subject RIL_16 | Val F1: 0.8541 | Test F1: 0.9118
# Early stopping in epoch 21. Best F1: 0.8497
# Fold 218 | Subject RIL_17 | Val F1: 0.8497 | Test F1: 0.2701
# Early stopping in epoch 26. Best F1: 0.8570
# Fold 219 | Subject RIL_18 | Val F1: 0.8570 | Test F1: 0.9566
# Early stopping in epoch 34. Best F1: 0.8549
# Fold 220 | Subject RIL_19 | Val F1: 0.8549 | Test F1: 0.9370
# Early stopping in epoch 26. Best F1: 0.8542
# Fold 221 | Subject RIL_2 | Val F1: 0.8542 | Test F1: 0.5588
# Early stopping in epoch 30. Best F1: 0.8544
# Fold 222 | Subject RIL_20 | Val F1: 0.8544 | Test F1: 0.9535
# Early stopping in epoch 18. Best F1: 0.8498
# Fold 223 | Subject RIL_21 | Val F1: 0.8498 | Test F1: 0.8577
# Early stopping in epoch 21. Best F1: 0.8540
# Fold 224 | Subject RIL_22 | Val F1: 0.8540 | Test F1: 0.7165
# Early stopping in epoch 27. Best F1: 0.8550
# Fold 225 | Subject RIL_23 | Val F1: 0.8550 | Test F1: 0.9081
# Early stopping in epoch 26. Best F1: 0.8533
# Fold 226 | Subject RIL_24 | Val F1: 0.8533 | Test F1: 0.8000
# Early stopping in epoch 31. Best F1: 0.8506
# Fold 227 | Subject RIL_25 | Val F1: 0.8506 | Test F1: 0.7395
# Early stopping in epoch 26. Best F1: 0.8536
# Fold 228 | Subject RIL_26 | Val F1: 0.8536 | Test F1: 0.8207
# Early stopping in epoch 25. Best F1: 0.8444
# Fold 229 | Subject RIL_27 | Val F1: 0.8444 | Test F1: 0.9181
# Early stopping in epoch 18. Best F1: 0.8470
# Fold 230 | Subject RIL_28 | Val F1: 0.8470 | Test F1: 0.8879
# Early stopping in epoch 23. Best F1: 0.8573
# Fold 231 | Subject RIL_29 | Val F1: 0.8573 | Test F1: 0.8279
# Early stopping in epoch 19. Best F1: 0.8612
# Fold 232 | Subject RIL_3 | Val F1: 0.8612 | Test F1: 0.8802
# Early stopping in epoch 23. Best F1: 0.8617
# Fold 233 | Subject RIL_30 | Val F1: 0.8617 | Test F1: 0.9471
# Early stopping in epoch 26. Best F1: 0.8623
# Fold 258 | Subject RIL_7 | Val F1: 0.8548 | Test F1: 0.8931
# Early stopping in epoch 20. Best F1: 0.8575
# Fold 259 | Subject RIL_8 | Val F1: 0.8575 | Test F1: 0.9563
# Early stopping in epoch 21. Best F1: 0.8594
# Fold 260 | Subject RIL_9 | Val F1: 0.8594 | Test F1: 0.7695
#
# Mean Test F1: 0.8637 ± 0.1142

# %% [markdown]
# ## Analysis

# %%
f1_scores = np.vstack((np.unique(subjects), results_list))
f1_scores = pd.DataFrame(f1_scores.T, columns=['patient', 'score'])
f1_scores.head()
# Out:
#   patient               score
# 0   ACL_1  0.8862443937175315
# 1  ACL_10  0.8451463718129019
# 2  ACL_11  0.9098511559737519
# 3   ACL_2  0.8703719164367764
# 4   ACL_3  0.9224786398826899

# %%
f1_scores.to_csv("../results/results_raw_LB_gait_cnnbilstm_window_norm.csv", index=False)

# %%
results_raw_LB_win_norm = pd.read_csv("../results/results_raw_LB_gait_cnnbilstm_window_norm.csv")

# %%
print(f'Mean f1-score: {np.mean(results_raw_LB_win_norm["score"])}')
print(f'Standard deviation: {np.std(results_raw_LB_win_norm["score"])}')
# Out:
# Mean f1-score: 0.8636745693611658
# Standard deviation: 0.11415373236410482

# %%
healthy = 'lightgreen'
ortho = 'lightcoral'
neuro = 'lightblue'

cohorts = {
    'HS': (("healthy", healthy), []),
    'ACL': (("ortho", ortho), []),
    'HOA': (("ortho", ortho), []),
    'KOA': (("ortho", ortho), []),
    'CIPN': (("neuro", neuro), []),
    'CVA': (("neuro", neuro), []),
    'PD': (("neuro", neuro), []),
    'RIL': (("neuro", neuro), [])}


for cohort in cohorts.keys():
    for patient_name in results_raw_LB_win_norm['patient']:
        if cohort in patient_name:
            score = results_raw_LB_win_norm.loc[results_raw_LB_win_norm['patient'] == patient_name, 'score'].values[0]
            cohorts[cohort][1].append(score)

mean = np.mean(results_raw_LB_win_norm["score"])

plt.figure(figsize=(12,8))

for cohort in cohorts.keys():
    bar = plt.bar(
        cohort,
        np.mean(cohorts[cohort][1]),
        yerr=np.std(cohorts[cohort][1]),
        capsize=5,
        label=cohorts[cohort][0][0],
        color=cohorts[cohort][0][1])

    plt.bar_label(bar, fmt='%.4f')

plt.axhline(y=mean, color='black', linestyle='--', label=f'Mean = {mean:.4f}')

plt.ylim(0.4, 1.05)

plt.legend()
plt.show()

# %% [markdown]
# # Prediction Visualization

# %%
best_subj_idx = np.argmax(results_raw_LB_win_norm['score'])
best_subj = results_raw_LB_win_norm.iloc[best_subj_idx]['patient'] 
print('Subject with the best score:')
print(results_raw_LB_win_norm.iloc[best_subj_idx])
print('')

worst_subj_idx = np.argmin(results_raw_LB_win_norm['score'])
worst_subj = results_raw_LB_win_norm.iloc[worst_subj_idx]['patient'] 
print('Subject with the worst score:')
print(results_raw_LB_win_norm.iloc[worst_subj_idx])
print('')
# Out:
# Subject with the best score:
# patient       RIL_6
# score      0.963344
# Name: 256, dtype: object
#
# Subject with the worst score:
# patient      RIL_17
# score      0.270142
# Name: 217, dtype: object

# %%
best_subj_trial = f"{best_subj}_1"  # Obtain first trial of the best classified subject 
worst_subj_trial = f"{worst_subj}_1"  # Obtain first trial of the worst classified subject 

print(best_subj_trial)
print(worst_subj_trial)
# Out:
# RIL_6_1
# RIL_17_1

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = best_subj_trial,   
    subject     = best_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"], 
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back_window_norm"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.9569

# %%
best_subj_meta = load_trial(base_path, best_subj_trial)
best_subj_meta = best_subj_meta["metadata"] 
best_subj_cohort = best_subj_meta["pathologyKey"] 
best_subj_group = best_subj_meta["group"] 

worst_subj_meta = load_trial(base_path, worst_subj_trial)
worst_subj_meta = worst_subj_meta["metadata"] 
worst_subj_cohort = worst_subj_meta["pathologyKey"] 
worst_subj_group = worst_subj_meta["group"]

# %%
path = base_path + f"/{best_subj_group}/{best_subj_cohort}/{best_subj}/{best_subj_trial}"

plot_gait_detection(
    y_true, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = worst_subj_trial,   
    subject     = worst_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"],
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back_window_norm"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.2806

# %%
path = base_path + f"/{worst_subj_group}/{worst_subj_cohort}/{worst_subj}/{worst_subj_trial}"

plot_gait_detection(
    y_true, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %% [markdown]
# After applying window normalization, the mean F1 score increased from 0.853 to 0.863. However, the worst subject still shows a very low F1 score (around 0.28).
#
# Visual inspection of the predictions reveals that the model correctly detects the timing of gait events. When a gait event occurs, the prediction aligns closely with the ground truth. However, the model frequently confuses the left and right classes. In other words, left events are often predicted as right events and vice versa, while the no-event class is predicted correctly.
#
# This suggests that the model is capable of detecting the presence of a step but struggles to determine which foot generated the event. This is a common issue that comes from the fact just the lower back sensor is being used. With just this sensor we successfully detect steps but we lack the laterality informaion that would help to correctly classify the most difficult examples.

# %% [markdown]
# # Back + Right Foot Sensor (raw)

# %% [markdown]
# ## Training

# %%
X, y, subjects = load_dataset_gait(base_path, process="raw", sensors=["LB", "RF"], window_size=200, stride=50)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
models_per_subject, results_list = train_model_cv(X, y, subjects, model_name="cnnbilstm", norm="window", epochs=100, lr=0.0003, patience=10, out_dir="../checkpoints/CNNBiLSTM/raw_LB_RF")
# Out:
# Early stopping in epoch 27. Best F1: 0.9228
# Fold 61 | Subject CVA_37 | Val F1: 0.9228 | Test F1: 0.8963
# Early stopping in epoch 32. Best F1: 0.9231
# Fold 62 | Subject CVA_38 | Val F1: 0.9231 | Test F1: 0.9540
# Early stopping in epoch 23. Best F1: 0.9210
# Fold 63 | Subject CVA_39 | Val F1: 0.9210 | Test F1: 0.9564
# Early stopping in epoch 48. Best F1: 0.9220
# Fold 64 | Subject CVA_4 | Val F1: 0.9220 | Test F1: 0.9335
# Early stopping in epoch 25. Best F1: 0.9234
# Fold 65 | Subject CVA_40 | Val F1: 0.9234 | Test F1: 0.9293
# Early stopping in epoch 20. Best F1: 0.9209
# Fold 66 | Subject CVA_41 | Val F1: 0.9209 | Test F1: 0.9512
# Early stopping in epoch 35. Best F1: 0.9231
# Fold 67 | Subject CVA_42 | Val F1: 0.9231 | Test F1: 0.9389
# Early stopping in epoch 18. Best F1: 0.9216
# Fold 68 | Subject CVA_43 | Val F1: 0.9216 | Test F1: 0.9297
# Early stopping in epoch 29. Best F1: 0.9242
# Fold 69 | Subject CVA_44 | Val F1: 0.9242 | Test F1: 0.9007
# Early stopping in epoch 28. Best F1: 0.9213
# Fold 70 | Subject CVA_45 | Val F1: 0.9213 | Test F1: 0.9327
# Early stopping in epoch 26. Best F1: 0.9231
# Fold 71 | Subject CVA_46 | Val F1: 0.9231 | Test F1: 0.9387
# Early stopping in epoch 21. Best F1: 0.9225
# Fold 72 | Subject CVA_47 | Val F1: 0.9225 | Test F1: 0.9380
# Early stopping in epoch 37. Best F1: 0.9231
# Fold 73 | Subject CVA_48 | Val F1: 0.9231 | Test F1: 0.9518
# Early stopping in epoch 28. Best F1: 0.9233
# Fold 74 | Subject CVA_49 | Val F1: 0.9233 | Test F1: 0.9335
# Early stopping in epoch 45. Best F1: 0.9240
# Fold 75 | Subject CVA_5 | Val F1: 0.9240 | Test F1: 0.8653
# Early stopping in epoch 31. Best F1: 0.9256
# Fold 76 | Subject CVA_6 | Val F1: 0.9256 | Test F1: 0.9134
# Early stopping in epoch 31. Best F1: 0.9256
# Fold 77 | Subject CVA_7 | Val F1: 0.9256 | Test F1: 0.8824
# Early stopping in epoch 47. Best F1: 0.9257
# Fold 78 | Subject CVA_8 | Val F1: 0.9257 | Test F1: 0.9562
# Early stopping in epoch 47. Best F1: 0.9247
# Fold 79 | Subject CVA_9 | Val F1: 0.9247 | Test F1: 0.6158
# Early stopping in epoch 26. Best F1: 0.9238
# Fold 80 | Subject HOA_1 | Val F1: 0.9238 | Test F1: 0.8827
# Early stopping in epoch 27. Best F1: 0.9242
# Fold 81 | Subject HOA_10 | Val F1: 0.9242 | Test F1: 0.9316
# Early stopping in epoch 29. Best F1: 0.9240
# Fold 82 | Subject HOA_11 | Val F1: 0.9240 | Test F1: 0.9622
# Early stopping in epoch 42. Best F1: 0.9243
# Early stopping in epoch 32. Best F1: 0.9228
# Fold 204 | Subject PD_4 | Val F1: 0.9228 | Test F1: 0.9504
# Early stopping in epoch 35. Best F1: 0.9227
# Fold 205 | Subject PD_5 | Val F1: 0.9227 | Test F1: 0.9436
# Early stopping in epoch 24. Best F1: 0.9222
# Fold 206 | Subject PD_6 | Val F1: 0.9222 | Test F1: 0.6129
# Early stopping in epoch 29. Best F1: 0.9116
# Fold 207 | Subject PD_7 | Val F1: 0.9116 | Test F1: 0.9654
# Early stopping in epoch 28. Best F1: 0.9126
# Fold 208 | Subject PD_8 | Val F1: 0.9126 | Test F1: 0.9446
# Early stopping in epoch 23. Best F1: 0.9130
# Fold 209 | Subject PD_9 | Val F1: 0.9130 | Test F1: 0.9616
# Early stopping in epoch 17. Best F1: 0.9115
# Fold 210 | Subject RIL_1 | Val F1: 0.9115 | Test F1: 0.9546
# Early stopping in epoch 29. Best F1: 0.9125
# Fold 211 | Subject RIL_10 | Val F1: 0.9125 | Test F1: 0.9532
# Early stopping in epoch 41. Best F1: 0.9135
# Fold 212 | Subject RIL_11 | Val F1: 0.9135 | Test F1: 0.9702
# Early stopping in epoch 22. Best F1: 0.9134
# Fold 213 | Subject RIL_12 | Val F1: 0.9134 | Test F1: 0.9041
# Early stopping in epoch 21. Best F1: 0.9097
# Fold 214 | Subject RIL_13 | Val F1: 0.9097 | Test F1: 0.9613
# Early stopping in epoch 45. Best F1: 0.9129
# Fold 215 | Subject RIL_14 | Val F1: 0.9129 | Test F1: 0.9612
# Early stopping in epoch 28. Best F1: 0.9124
# Fold 216 | Subject RIL_15 | Val F1: 0.9124 | Test F1: 0.6265
# Early stopping in epoch 17. Best F1: 0.9078
# Fold 217 | Subject RIL_16 | Val F1: 0.9078 | Test F1: 0.9342
# Early stopping in epoch 27. Best F1: 0.9120
# Fold 218 | Subject RIL_17 | Val F1: 0.9120 | Test F1: 0.9138
# Early stopping in epoch 17. Best F1: 0.9100
# Fold 219 | Subject RIL_18 | Val F1: 0.9100 | Test F1: 0.9658
# Early stopping in epoch 30. Best F1: 0.9103
# Fold 220 | Subject RIL_19 | Val F1: 0.9103 | Test F1: 0.9581
# Early stopping in epoch 36. Best F1: 0.9102
# Fold 221 | Subject RIL_2 | Val F1: 0.9102 | Test F1: 0.7834
# Early stopping in epoch 30. Best F1: 0.9107
# Fold 222 | Subject RIL_20 | Val F1: 0.9107 | Test F1: 0.9562
# Early stopping in epoch 39. Best F1: 0.9105
# Fold 223 | Subject RIL_21 | Val F1: 0.9105 | Test F1: 0.9339
# Early stopping in epoch 49. Best F1: 0.9106
# Fold 224 | Subject RIL_22 | Val F1: 0.9106 | Test F1: 0.8832
# Early stopping in epoch 53. Best F1: 0.9125
# Fold 225 | Subject RIL_23 | Val F1: 0.9125 | Test F1: 0.9333
# Early stopping in epoch 21. Best F1: 0.9122
# Fold 226 | Subject RIL_24 | Val F1: 0.9122 | Test F1: 0.7954
# Early stopping in epoch 35. Best F1: 0.9104
# Fold 227 | Subject RIL_25 | Val F1: 0.9104 | Test F1: 0.7952
# Early stopping in epoch 28. Best F1: 0.9110
# Fold 228 | Subject RIL_26 | Val F1: 0.9110 | Test F1: 0.8534
# Early stopping in epoch 15. Best F1: 0.9044
# Fold 229 | Subject RIL_27 | Val F1: 0.9044 | Test F1: 0.9422
# Early stopping in epoch 25. Best F1: 0.9059
# Fold 230 | Subject RIL_28 | Val F1: 0.9059 | Test F1: 0.9123
# Early stopping in epoch 32. Best F1: 0.9089
# Fold 231 | Subject RIL_29 | Val F1: 0.9089 | Test F1: 0.8969
# Early stopping in epoch 29. Best F1: 0.9091
# Fold 232 | Subject RIL_3 | Val F1: 0.9091 | Test F1: 0.9295
# Early stopping in epoch 19. Best F1: 0.9069
# Fold 233 | Subject RIL_30 | Val F1: 0.9069 | Test F1: 0.9579
# Early stopping in epoch 28. Best F1: 0.9083
# Fold 234 | Subject RIL_31 | Val F1: 0.9083 | Test F1: 0.7836
# Early stopping in epoch 25. Best F1: 0.9084
# Fold 235 | Subject RIL_32 | Val F1: 0.9084 | Test F1: 0.8520
# Early stopping in epoch 28. Best F1: 0.9093
# Fold 236 | Subject RIL_33 | Val F1: 0.9093 | Test F1: 0.9671
# Early stopping in epoch 37. Best F1: 0.9086
# Fold 237 | Subject RIL_34 | Val F1: 0.9086 | Test F1: 0.9668
# Early stopping in epoch 15. Best F1: 0.9069
# Fold 238 | Subject RIL_35 | Val F1: 0.9069 | Test F1: 0.9610
# Early stopping in epoch 28. Best F1: 0.9081
# Fold 239 | Subject RIL_36 | Val F1: 0.9081 | Test F1: 0.9692
# Early stopping in epoch 26. Best F1: 0.9088
# Fold 240 | Subject RIL_37 | Val F1: 0.9088 | Test F1: 0.8691
# Early stopping in epoch 21. Best F1: 0.9077
# Fold 241 | Subject RIL_38 | Val F1: 0.9077 | Test F1: 0.9283
# Early stopping in epoch 28. Best F1: 0.9094
# Fold 242 | Subject RIL_39 | Val F1: 0.9094 | Test F1: 0.9313
# Early stopping in epoch 27. Best F1: 0.9103
# Fold 243 | Subject RIL_4 | Val F1: 0.9103 | Test F1: 0.9145
# Early stopping in epoch 20. Best F1: 0.9083
# Fold 244 | Subject RIL_40 | Val F1: 0.9083 | Test F1: 0.9510
# Early stopping in epoch 30. Best F1: 0.9094
# Fold 245 | Subject RIL_41 | Val F1: 0.9094 | Test F1: 0.9585
# Early stopping in epoch 27. Best F1: 0.9084
# Fold 246 | Subject RIL_42 | Val F1: 0.9084 | Test F1: 0.5900
# Early stopping in epoch 16. Best F1: 0.9067
# Fold 247 | Subject RIL_43 | Val F1: 0.9067 | Test F1: 0.7600
# Early stopping in epoch 24. Best F1: 0.9082
# Fold 248 | Subject RIL_44 | Val F1: 0.9082 | Test F1: 0.9123
# Early stopping in epoch 21. Best F1: 0.9078
# Fold 249 | Subject RIL_45 | Val F1: 0.9078 | Test F1: 0.9456
# Early stopping in epoch 34. Best F1: 0.9091
# Fold 250 | Subject RIL_46 | Val F1: 0.9091 | Test F1: 0.9290
# Early stopping in epoch 17. Best F1: 0.9088
# Fold 251 | Subject RIL_47 | Val F1: 0.9088 | Test F1: 0.9412
# Early stopping in epoch 46. Best F1: 0.9080
# Fold 252 | Subject RIL_48 | Val F1: 0.9080 | Test F1: 0.9371
# Early stopping in epoch 34. Best F1: 0.9089
# Fold 253 | Subject RIL_49 | Val F1: 0.9089 | Test F1: 0.5677
# Early stopping in epoch 27. Best F1: 0.9081
# Fold 254 | Subject RIL_5 | Val F1: 0.9081 | Test F1: 0.9314
# Early stopping in epoch 18. Best F1: 0.9068
# Fold 255 | Subject RIL_50 | Val F1: 0.9068 | Test F1: 0.8473
# Early stopping in epoch 20. Best F1: 0.9064
# Fold 256 | Subject RIL_51 | Val F1: 0.9064 | Test F1: 0.9391
# Early stopping in epoch 22. Best F1: 0.9081
# Fold 257 | Subject RIL_6 | Val F1: 0.9081 | Test F1: 0.9785
# Early stopping in epoch 42. Best F1: 0.9102
# Fold 258 | Subject RIL_7 | Val F1: 0.9102 | Test F1: 0.9045
# Early stopping in epoch 36. Best F1: 0.9078
# Fold 259 | Subject RIL_8 | Val F1: 0.9078 | Test F1: 0.9660
# Early stopping in epoch 19. Best F1: 0.9064
# Fold 260 | Subject RIL_9 | Val F1: 0.9064 | Test F1: 0.8607
#
# Mean Test F1: 0.9093 ± 0.0851

# %% [markdown]
# ## Analysis

# %%
f1_scores = np.vstack((np.unique(subjects), results_list))
f1_scores = pd.DataFrame(f1_scores.T, columns=['patient', 'score'])
f1_scores.head()
# Out:
#   patient               score
# 0   ACL_1  0.9374032778852738
# 1  ACL_10  0.9675722253823215
# 2  ACL_11  0.9589433629233781
# 3   ACL_2  0.9166708464531287
# 4   ACL_3  0.9133461826450477

# %%
f1_scores.to_csv("../results/results_raw_LB_RF.csv", index=False)

# %%
results_raw_LB_RF = pd.read_csv("../results/results_raw_LB_RF.csv")

# %%
print(f'Mean f1-score: {np.mean(results_raw_LB_RF["score"])}')
print(f'Standard deviation: {np.std(results_raw_LB_RF["score"])}')
# Out:
# Mean f1-score: 0.9092569150451538
# Standard deviation: 0.08511388583998467

# %%
healthy = 'lightgreen'
ortho = 'lightcoral'
neuro = 'lightblue'

cohorts = {
    'HS': (("healthy", healthy), []),
    'ACL': (("ortho", ortho), []),
    'HOA': (("ortho", ortho), []),
    'KOA': (("ortho", ortho), []),
    'CIPN': (("neuro", neuro), []),
    'CVA': (("neuro", neuro), []),
    'PD': (("neuro", neuro), []),
    'RIL': (("neuro", neuro), [])}


for cohort in cohorts.keys():
    for patient_name in results_raw_LB_RF['patient']:
        if cohort in patient_name:
            score = results_raw_LB_RF.loc[results_raw_LB_RF['patient'] == patient_name, 'score'].values[0]
            cohorts[cohort][1].append(score)

mean = np.mean(results_raw_LB_RF["score"])

plt.figure(figsize=(12,8))

for cohort in cohorts.keys():
    bar = plt.bar(
        cohort,
        np.mean(cohorts[cohort][1]),
        yerr=np.std(cohorts[cohort][1]),
        capsize=5,
        label=cohorts[cohort][0][0],
        color=cohorts[cohort][0][1])

    plt.bar_label(bar, fmt='%.4f')

plt.axhline(y=mean, color='black', linestyle='--', label=f'Mean = {mean:.4f}')

plt.ylim(0.4, 1.05)

plt.legend()
plt.show()

# %% [markdown]
# # Prediction Visualization

# %%
best_subj_idx = np.argmax(results_raw_LB_RF['score'])
best_subj = results_raw_LB_RF.iloc[best_subj_idx]['patient'] 
print('Subject with the best score:')
print(results_raw_LB_RF.iloc[best_subj_idx])
print('')

worst_subj_idx = np.argmin(results_raw_LB_RF['score'])
worst_subj = results_raw_LB_RF.iloc[worst_subj_idx]['patient'] 
print('Subject with the worst score:')
print(results_raw_LB_RF.iloc[worst_subj_idx])
print('')
# Out:
# Subject with the best score:
# patient       RIL_6
# score      0.978505
# Name: 256, dtype: object
#
# Subject with the worst score:
# patient     CVA_21
# score      0.42723
# Name: 43, dtype: object

# %%
best_subj_trial = f"{best_subj}_1"  # Obtain first trial of the best classified subject 
worst_subj_trial = f"{worst_subj}_1"  # Obtain first trial of the worst classified subject 

print(best_subj_trial)
print(worst_subj_trial)
# Out:
# RIL_6_1
# CVA_21_1

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = best_subj_trial,   
    subject     = best_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"], 
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back_window_norm"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.9569

# %%
best_subj_meta = load_trial(base_path, best_subj_trial)
best_subj_meta = best_subj_meta["metadata"] 
best_subj_cohort = best_subj_meta["pathologyKey"] 
best_subj_group = best_subj_meta["group"] 

worst_subj_meta = load_trial(base_path, worst_subj_trial)
worst_subj_meta = worst_subj_meta["metadata"] 
worst_subj_cohort = worst_subj_meta["pathologyKey"] 
worst_subj_group = worst_subj_meta["group"]

# %%
path = base_path + f"/{best_subj_group}/{best_subj_cohort}/{best_subj}/{best_subj_trial}"

plot_gait_detection(
    y_true, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = worst_subj_trial,   
    subject     = worst_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"],
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back_window_norm"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.8271

# %%
path = base_path + f"/{worst_subj_group}/{worst_subj_cohort}/{worst_subj}/{worst_subj_trial}"

plot_gait_detection(
    y_true, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

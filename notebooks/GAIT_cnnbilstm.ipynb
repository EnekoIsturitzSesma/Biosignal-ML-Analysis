# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gc 
from sklearn.metrics import f1_score

import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.load_data_gait import *
from src.plot_data_gait import *
from src.train_LSTMGait import train_model_cv, predict_trial

# %%
base_path = '../datasets/GAIT_signals/dataset/data'

# %% [markdown]
# # Only Back Sensor (raw)

# %% [markdown]
# ## Training

# %%
X, y, subjects = load_dataset_gait(base_path, process="raw", sensors=["LB"], window_size=200, stride=50)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
models_per_subject, results_list = train_model_cv(X, y, subjects, model_name="cnnbilstm", epochs=100, lr=0.0003, patience=10, out_dir="../checkpoints/CNNBiLSTM/raw_only_back")
# Out:
# Early stopping in epoch 40. Best F1: 0.8859
# Fold 1 | Subject ACL_1 | Val F1: 0.8859 | Test F1: 0.9122
# Early stopping in epoch 34. Best F1: 0.8850
# Fold 2 | Subject ACL_10 | Val F1: 0.8850 | Test F1: 0.8443
# Early stopping in epoch 27. Best F1: 0.8836
# Fold 3 | Subject ACL_11 | Val F1: 0.8836 | Test F1: 0.9334
# Early stopping in epoch 25. Best F1: 0.8868
# Fold 4 | Subject ACL_2 | Val F1: 0.8868 | Test F1: 0.8960
# Early stopping in epoch 19. Best F1: 0.8811
# Fold 5 | Subject ACL_3 | Val F1: 0.8811 | Test F1: 0.8667
# Early stopping in epoch 20. Best F1: 0.8843
# Fold 6 | Subject ACL_4 | Val F1: 0.8843 | Test F1: 0.8920
# Early stopping in epoch 50. Best F1: 0.8862
# Fold 7 | Subject ACL_5 | Val F1: 0.8862 | Test F1: 0.6756
# Early stopping in epoch 32. Best F1: 0.8783
# Fold 8 | Subject ACL_6 | Val F1: 0.8783 | Test F1: 0.9262
# Early stopping in epoch 30. Best F1: 0.8848
# Fold 9 | Subject ACL_7 | Val F1: 0.8848 | Test F1: 0.9110
# Early stopping in epoch 21. Best F1: 0.8825
# Fold 10 | Subject ACL_8 | Val F1: 0.8825 | Test F1: 0.8622
# Early stopping in epoch 27. Best F1: 0.8811
# Fold 11 | Subject ACL_9 | Val F1: 0.8811 | Test F1: 0.8935
# Early stopping in epoch 14. Best F1: 0.8775
# Fold 12 | Subject CIPN_1 | Val F1: 0.8775 | Test F1: 0.9239
# Early stopping in epoch 31. Best F1: 0.8787
# Fold 13 | Subject CIPN_10 | Val F1: 0.8787 | Test F1: 0.9498
# Early stopping in epoch 47. Best F1: 0.8808
# Fold 14 | Subject CIPN_11 | Val F1: 0.8808 | Test F1: 0.9678
# Early stopping in epoch 33. Best F1: 0.8791
# Fold 15 | Subject CIPN_12 | Val F1: 0.8791 | Test F1: 0.9504
# Early stopping in epoch 23. Best F1: 0.8766
# Fold 16 | Subject CIPN_13 | Val F1: 0.8766 | Test F1: 0.9465
# Early stopping in epoch 27. Best F1: 0.8789
# Fold 17 | Subject CIPN_14 | Val F1: 0.8789 | Test F1: 0.9517
# Early stopping in epoch 19. Best F1: 0.8754
# Fold 18 | Subject CIPN_15 | Val F1: 0.8754 | Test F1: 0.9342
# Early stopping in epoch 39. Best F1: 0.8800
# Fold 19 | Subject CIPN_16 | Val F1: 0.8800 | Test F1: 0.9283
# Early stopping in epoch 36. Best F1: 0.8838
# Fold 20 | Subject CIPN_17 | Val F1: 0.8838 | Test F1: 0.7922
# Early stopping in epoch 45. Best F1: 0.8735
# Fold 21 | Subject CIPN_18 | Val F1: 0.8735 | Test F1: 0.9171
# Early stopping in epoch 32. Best F1: 0.8764
# Fold 22 | Subject CIPN_19 | Val F1: 0.8764 | Test F1: 0.9434
# Early stopping in epoch 24. Best F1: 0.8720
# Fold 23 | Subject CIPN_2 | Val F1: 0.8720 | Test F1: 0.9617
# Early stopping in epoch 21. Best F1: 0.8739
# Fold 24 | Subject CIPN_3 | Val F1: 0.8739 | Test F1: 0.6172
# Early stopping in epoch 34. Best F1: 0.8697
# Fold 25 | Subject CIPN_4 | Val F1: 0.8697 | Test F1: 0.9238
# Early stopping in epoch 32. Best F1: 0.8688
# Fold 26 | Subject CIPN_5 | Val F1: 0.8688 | Test F1: 0.9278
# Early stopping in epoch 20. Best F1: 0.8704
# Fold 27 | Subject CIPN_6 | Val F1: 0.8704 | Test F1: 0.9221
# Early stopping in epoch 26. Best F1: 0.8710
# Fold 28 | Subject CIPN_7 | Val F1: 0.8710 | Test F1: 0.9611
# Early stopping in epoch 23. Best F1: 0.8740
# Fold 29 | Subject CIPN_8 | Val F1: 0.8740 | Test F1: 0.9194
# Early stopping in epoch 19. Best F1: 0.8681
# Fold 30 | Subject CIPN_9 | Val F1: 0.8681 | Test F1: 0.9492
# Early stopping in epoch 26. Best F1: 0.8719
# Fold 31 | Subject CVA_1 | Val F1: 0.8719 | Test F1: 0.8899
# Early stopping in epoch 29. Best F1: 0.8757
# Fold 32 | Subject CVA_10 | Val F1: 0.8757 | Test F1: 0.7981
# Early stopping in epoch 26. Best F1: 0.8698
# Fold 33 | Subject CVA_11 | Val F1: 0.8698 | Test F1: 0.8520
# Early stopping in epoch 32. Best F1: 0.8731
# Fold 34 | Subject CVA_12 | Val F1: 0.8731 | Test F1: 0.8633
# Early stopping in epoch 22. Best F1: 0.8713
# Fold 35 | Subject CVA_13 | Val F1: 0.8713 | Test F1: 0.8995
# Early stopping in epoch 31. Best F1: 0.8753
# Fold 36 | Subject CVA_14 | Val F1: 0.8753 | Test F1: 0.8578
# Early stopping in epoch 40. Best F1: 0.8727
# Fold 37 | Subject CVA_15 | Val F1: 0.8727 | Test F1: 0.9211
# Early stopping in epoch 26. Best F1: 0.8652
# Fold 38 | Subject CVA_16 | Val F1: 0.8652 | Test F1: 0.9297
# Early stopping in epoch 18. Best F1: 0.8655
# Fold 39 | Subject CVA_17 | Val F1: 0.8655 | Test F1: 0.7956
# Early stopping in epoch 22. Best F1: 0.8697
# Fold 40 | Subject CVA_18 | Val F1: 0.8697 | Test F1: 0.8062
# Early stopping in epoch 23. Best F1: 0.8697
# Fold 41 | Subject CVA_19 | Val F1: 0.8697 | Test F1: 0.8795
# Early stopping in epoch 32. Best F1: 0.8747
# Fold 42 | Subject CVA_2 | Val F1: 0.8747 | Test F1: 0.8835
# Early stopping in epoch 17. Best F1: 0.8696
# Fold 43 | Subject CVA_20 | Val F1: 0.8696 | Test F1: 0.6809
# Early stopping in epoch 29. Best F1: 0.8703
# Fold 44 | Subject CVA_21 | Val F1: 0.8703 | Test F1: 0.2913
# Early stopping in epoch 20. Best F1: 0.8721
# Fold 45 | Subject CVA_22 | Val F1: 0.8721 | Test F1: 0.7376
# Early stopping in epoch 43. Best F1: 0.8701
# Fold 46 | Subject CVA_23 | Val F1: 0.8701 | Test F1: 0.9204
# Early stopping in epoch 26. Best F1: 0.8712
# Fold 47 | Subject CVA_24 | Val F1: 0.8712 | Test F1: 0.8900
# Early stopping in epoch 25. Best F1: 0.8757
# Fold 48 | Subject CVA_25 | Val F1: 0.8757 | Test F1: 0.8402
# Early stopping in epoch 47. Best F1: 0.8728
# Fold 49 | Subject CVA_26 | Val F1: 0.8728 | Test F1: 0.9350
# Early stopping in epoch 27. Best F1: 0.8718
# Fold 50 | Subject CVA_27 | Val F1: 0.8718 | Test F1: 0.8844
# Early stopping in epoch 20. Best F1: 0.8726
# Fold 51 | Subject CVA_28 | Val F1: 0.8726 | Test F1: 0.8952
# Early stopping in epoch 23. Best F1: 0.8717
# Fold 52 | Subject CVA_29 | Val F1: 0.8717 | Test F1: 0.9220
# Early stopping in epoch 30. Best F1: 0.8749
# Fold 53 | Subject CVA_3 | Val F1: 0.8749 | Test F1: 0.9218
# Early stopping in epoch 27. Best F1: 0.8729
# Fold 54 | Subject CVA_30 | Val F1: 0.8729 | Test F1: 0.9523
# Early stopping in epoch 19. Best F1: 0.8752
# Fold 55 | Subject CVA_31 | Val F1: 0.8752 | Test F1: 0.9129
# Early stopping in epoch 34. Best F1: 0.8703
# Fold 56 | Subject CVA_32 | Val F1: 0.8703 | Test F1: 0.9193
# Early stopping in epoch 26. Best F1: 0.8793
# Fold 57 | Subject CVA_33 | Val F1: 0.8793 | Test F1: 0.6781
# Early stopping in epoch 36. Best F1: 0.8773
# Fold 58 | Subject CVA_34 | Val F1: 0.8773 | Test F1: 0.9181
# Early stopping in epoch 42. Best F1: 0.8820
# Fold 59 | Subject CVA_35 | Val F1: 0.8820 | Test F1: 0.9323
# Early stopping in epoch 25. Best F1: 0.8738
# Fold 60 | Subject CVA_36 | Val F1: 0.8738 | Test F1: 0.8739
# Early stopping in epoch 27. Best F1: 0.8819
# Fold 61 | Subject CVA_37 | Val F1: 0.8819 | Test F1: 0.8241
# Early stopping in epoch 19. Best F1: 0.8742
# Fold 62 | Subject CVA_38 | Val F1: 0.8742 | Test F1: 0.9192
# Early stopping in epoch 33. Best F1: 0.8788
# Fold 63 | Subject CVA_39 | Val F1: 0.8788 | Test F1: 0.9268
# Early stopping in epoch 30. Best F1: 0.8751
# Fold 64 | Subject CVA_4 | Val F1: 0.8751 | Test F1: 0.8870
# Early stopping in epoch 28. Best F1: 0.8758
# Fold 65 | Subject CVA_40 | Val F1: 0.8758 | Test F1: 0.8866
# Early stopping in epoch 32. Best F1: 0.8809
# Fold 66 | Subject CVA_41 | Val F1: 0.8809 | Test F1: 0.9057
# Early stopping in epoch 22. Best F1: 0.8740
# Early stopping in epoch 35. Best F1: 0.8796
# Fold 91 | Subject HOA_6 | Val F1: 0.8796 | Test F1: 0.9433
# Early stopping in epoch 36. Best F1: 0.8793
# Fold 92 | Subject HOA_7 | Val F1: 0.8793 | Test F1: 0.4798
# Early stopping in epoch 36. Best F1: 0.8797
# Fold 93 | Subject HOA_8 | Val F1: 0.8797 | Test F1: 0.9370
# Early stopping in epoch 38. Best F1: 0.8795
# Fold 94 | Subject HOA_9 | Val F1: 0.8795 | Test F1: 0.9237
# Early stopping in epoch 28. Best F1: 0.8757
# Fold 95 | Subject HS_1 | Val F1: 0.8757 | Test F1: 0.8596
# Early stopping in epoch 27. Best F1: 0.8824
# Fold 96 | Subject HS_10 | Val F1: 0.8824 | Test F1: 0.7515
# Early stopping in epoch 49. Best F1: 0.8816
# Fold 97 | Subject HS_11 | Val F1: 0.8816 | Test F1: 0.8726
# Early stopping in epoch 29. Best F1: 0.8812
# Fold 98 | Subject HS_12 | Val F1: 0.8812 | Test F1: 0.9237
# Early stopping in epoch 22. Best F1: 0.8795
# Fold 99 | Subject HS_13 | Val F1: 0.8795 | Test F1: 0.8906
# Early stopping in epoch 28. Best F1: 0.8796
# Fold 100 | Subject HS_14 | Val F1: 0.8796 | Test F1: 0.8148
# Early stopping in epoch 63. Best F1: 0.8807
# Fold 101 | Subject HS_15 | Val F1: 0.8807 | Test F1: 0.7672
# Early stopping in epoch 22. Best F1: 0.8761
# Fold 102 | Subject HS_16 | Val F1: 0.8761 | Test F1: 0.8966
# Early stopping in epoch 31. Best F1: 0.8787
# Fold 103 | Subject HS_17 | Val F1: 0.8787 | Test F1: 0.9224
# Early stopping in epoch 27. Best F1: 0.8773
# Fold 104 | Subject HS_18 | Val F1: 0.8773 | Test F1: 0.8029
# Early stopping in epoch 38. Best F1: 0.8790
# Fold 105 | Subject HS_19 | Val F1: 0.8790 | Test F1: 0.9193
# Early stopping in epoch 25. Best F1: 0.8825
# Fold 106 | Subject HS_2 | Val F1: 0.8825 | Test F1: 0.5637
# Early stopping in epoch 45. Best F1: 0.8833
# Fold 107 | Subject HS_20 | Val F1: 0.8833 | Test F1: 0.4719
# Early stopping in epoch 28. Best F1: 0.8831
# Fold 108 | Subject HS_21 | Val F1: 0.8831 | Test F1: 0.7843
# Early stopping in epoch 22. Best F1: 0.8823
# Fold 109 | Subject HS_22 | Val F1: 0.8823 | Test F1: 0.9295
# Early stopping in epoch 30. Best F1: 0.8846
# Fold 110 | Subject HS_23 | Val F1: 0.8846 | Test F1: 0.8372
# Early stopping in epoch 28. Best F1: 0.8826
# Fold 111 | Subject HS_24 | Val F1: 0.8826 | Test F1: 0.7336
# Early stopping in epoch 19. Best F1: 0.8813
# Fold 112 | Subject HS_25 | Val F1: 0.8813 | Test F1: 0.8679
# Early stopping in epoch 18. Best F1: 0.8856
# Fold 113 | Subject HS_26 | Val F1: 0.8856 | Test F1: 0.9495
# Early stopping in epoch 29. Best F1: 0.8873
# Fold 114 | Subject HS_27 | Val F1: 0.8873 | Test F1: 0.8891
# Early stopping in epoch 36. Best F1: 0.8881
# Fold 115 | Subject HS_28 | Val F1: 0.8881 | Test F1: 0.7928
# Early stopping in epoch 28. Best F1: 0.8878
# Fold 116 | Subject HS_29 | Val F1: 0.8878 | Test F1: 0.9424
# Early stopping in epoch 26. Best F1: 0.8846
# Fold 117 | Subject HS_3 | Val F1: 0.8846 | Test F1: 0.9503
# Early stopping in epoch 27. Best F1: 0.8858
# Fold 118 | Subject HS_30 | Val F1: 0.8858 | Test F1: 0.9214
# Early stopping in epoch 20. Best F1: 0.8825
# Fold 119 | Subject HS_31 | Val F1: 0.8825 | Test F1: 0.9466
# Early stopping in epoch 19. Best F1: 0.8862
# Fold 120 | Subject HS_32 | Val F1: 0.8862 | Test F1: 0.8974
# Early stopping in epoch 19. Best F1: 0.8831
# Fold 121 | Subject HS_33 | Val F1: 0.8831 | Test F1: 0.9509
# Early stopping in epoch 40. Best F1: 0.8861
# Fold 122 | Subject HS_34 | Val F1: 0.8861 | Test F1: 0.7557
# Early stopping in epoch 29. Best F1: 0.8849
# Fold 123 | Subject HS_35 | Val F1: 0.8849 | Test F1: 0.7653
# Early stopping in epoch 21. Best F1: 0.8800
# Fold 124 | Subject HS_36 | Val F1: 0.8800 | Test F1: 0.7990
# Early stopping in epoch 31. Best F1: 0.8811
# Fold 125 | Subject HS_37 | Val F1: 0.8811 | Test F1: 0.8551
# Early stopping in epoch 23. Best F1: 0.8839
# Fold 126 | Subject HS_38 | Val F1: 0.8839 | Test F1: 0.9298
# Early stopping in epoch 34. Best F1: 0.8823
# Fold 127 | Subject HS_39 | Val F1: 0.8823 | Test F1: 0.9275
# Early stopping in epoch 21. Best F1: 0.8814
# Fold 128 | Subject HS_4 | Val F1: 0.8814 | Test F1: 0.9364
# Early stopping in epoch 29. Best F1: 0.8833
# Fold 129 | Subject HS_40 | Val F1: 0.8833 | Test F1: 0.8759
# Early stopping in epoch 21. Best F1: 0.8846
# Fold 130 | Subject HS_41 | Val F1: 0.8846 | Test F1: 0.7751
# Early stopping in epoch 21. Best F1: 0.8774
# Fold 131 | Subject HS_42 | Val F1: 0.8774 | Test F1: 0.8853
# Early stopping in epoch 24. Best F1: 0.8839
# Fold 132 | Subject HS_43 | Val F1: 0.8839 | Test F1: 0.8328
# Early stopping in epoch 27. Best F1: 0.8892
# Fold 133 | Subject HS_44 | Val F1: 0.8892 | Test F1: 0.9326
# Early stopping in epoch 19. Best F1: 0.8787
# Fold 134 | Subject HS_45 | Val F1: 0.8787 | Test F1: 0.8925
# Early stopping in epoch 20. Best F1: 0.8853
# Fold 135 | Subject HS_46 | Val F1: 0.8853 | Test F1: 0.9260
# Early stopping in epoch 38. Best F1: 0.8852
# Fold 136 | Subject HS_47 | Val F1: 0.8852 | Test F1: 0.9179
# Early stopping in epoch 40. Best F1: 0.8879
# Fold 137 | Subject HS_48 | Val F1: 0.8879 | Test F1: 0.9350
# Early stopping in epoch 28. Best F1: 0.8818
# Fold 138 | Subject HS_49 | Val F1: 0.8818 | Test F1: 0.8464
# Early stopping in epoch 16. Best F1: 0.8781
# Fold 212 | Subject RIL_11 | Val F1: 0.8676 | Test F1: 0.9528
# Early stopping in epoch 25. Best F1: 0.8638
# Fold 213 | Subject RIL_12 | Val F1: 0.8638 | Test F1: 0.6411
# Early stopping in epoch 42. Best F1: 0.8448
# Fold 214 | Subject RIL_13 | Val F1: 0.8448 | Test F1: 0.9385
# Early stopping in epoch 38. Best F1: 0.8448
# Fold 215 | Subject RIL_14 | Val F1: 0.8448 | Test F1: 0.9476
# Early stopping in epoch 22. Best F1: 0.8423
# Fold 216 | Subject RIL_15 | Val F1: 0.8423 | Test F1: 0.7794
# Early stopping in epoch 37. Best F1: 0.8513
# Fold 217 | Subject RIL_16 | Val F1: 0.8513 | Test F1: 0.9137
# Early stopping in epoch 30. Best F1: 0.8467
# Fold 218 | Subject RIL_17 | Val F1: 0.8467 | Test F1: 0.2717
# Early stopping in epoch 28. Best F1: 0.8449
# Fold 219 | Subject RIL_18 | Val F1: 0.8449 | Test F1: 0.9589
# Early stopping in epoch 24. Best F1: 0.8429
# Fold 220 | Subject RIL_19 | Val F1: 0.8429 | Test F1: 0.9181
# Early stopping in epoch 29. Best F1: 0.8461
# Fold 221 | Subject RIL_2 | Val F1: 0.8461 | Test F1: 0.6530
# Early stopping in epoch 40. Best F1: 0.8486
# Fold 222 | Subject RIL_20 | Val F1: 0.8486 | Test F1: 0.9501
# Early stopping in epoch 17. Best F1: 0.8424
# Fold 223 | Subject RIL_21 | Val F1: 0.8424 | Test F1: 0.2807
# Early stopping in epoch 37. Best F1: 0.8472
# Fold 224 | Subject RIL_22 | Val F1: 0.8472 | Test F1: 0.5832
# Early stopping in epoch 28. Best F1: 0.8458
# Fold 225 | Subject RIL_23 | Val F1: 0.8458 | Test F1: 0.9056
# Early stopping in epoch 25. Best F1: 0.8400
# Fold 226 | Subject RIL_24 | Val F1: 0.8400 | Test F1: 0.8001
# Early stopping in epoch 42. Best F1: 0.8457
# Fold 227 | Subject RIL_25 | Val F1: 0.8457 | Test F1: 0.6281
# Early stopping in epoch 32. Best F1: 0.8470
# Fold 228 | Subject RIL_26 | Val F1: 0.8470 | Test F1: 0.5635
# Early stopping in epoch 20. Best F1: 0.8289
# Fold 229 | Subject RIL_27 | Val F1: 0.8289 | Test F1: 0.9072
# Early stopping in epoch 21. Best F1: 0.8262
# Fold 230 | Subject RIL_28 | Val F1: 0.8262 | Test F1: 0.8950
# Early stopping in epoch 15. Best F1: 0.8315
# Fold 231 | Subject RIL_29 | Val F1: 0.8315 | Test F1: 0.8736
# Early stopping in epoch 31. Best F1: 0.8370
# Fold 232 | Subject RIL_3 | Val F1: 0.8370 | Test F1: 0.8734
# Early stopping in epoch 26. Best F1: 0.8322
# Fold 233 | Subject RIL_30 | Val F1: 0.8322 | Test F1: 0.9352
# Early stopping in epoch 36. Best F1: 0.8345
# Fold 234 | Subject RIL_31 | Val F1: 0.8345 | Test F1: 0.8006
# Early stopping in epoch 26. Best F1: 0.8393
# Fold 235 | Subject RIL_32 | Val F1: 0.8393 | Test F1: 0.7141
# Early stopping in epoch 28. Best F1: 0.8387
# Fold 236 | Subject RIL_33 | Val F1: 0.8387 | Test F1: 0.9494
# Early stopping in epoch 23. Best F1: 0.8294
# Fold 237 | Subject RIL_34 | Val F1: 0.8294 | Test F1: 0.9479
# Early stopping in epoch 25. Best F1: 0.8389
# Fold 238 | Subject RIL_35 | Val F1: 0.8389 | Test F1: 0.9216
# Early stopping in epoch 30. Best F1: 0.8382
# Fold 239 | Subject RIL_36 | Val F1: 0.8382 | Test F1: 0.9064
# Early stopping in epoch 24. Best F1: 0.8390
# Fold 240 | Subject RIL_37 | Val F1: 0.8390 | Test F1: 0.8030
# Early stopping in epoch 23. Best F1: 0.8377
# Fold 241 | Subject RIL_38 | Val F1: 0.8377 | Test F1: 0.8718
# Early stopping in epoch 27. Best F1: 0.8343
# Fold 242 | Subject RIL_39 | Val F1: 0.8343 | Test F1: 0.8297
# Early stopping in epoch 25. Best F1: 0.8390
# Fold 243 | Subject RIL_4 | Val F1: 0.8390 | Test F1: 0.8299
# Early stopping in epoch 22. Best F1: 0.8358
# Fold 244 | Subject RIL_40 | Val F1: 0.8358 | Test F1: 0.9387
# Early stopping in epoch 41. Best F1: 0.8391
# Fold 245 | Subject RIL_41 | Val F1: 0.8391 | Test F1: 0.9112
# Early stopping in epoch 26. Best F1: 0.8322
# Fold 246 | Subject RIL_42 | Val F1: 0.8322 | Test F1: 0.4201
# Early stopping in epoch 33. Best F1: 0.8384
# Fold 247 | Subject RIL_43 | Val F1: 0.8384 | Test F1: 0.8144
# Early stopping in epoch 22. Best F1: 0.8394
# Fold 248 | Subject RIL_44 | Val F1: 0.8394 | Test F1: 0.9193
# Early stopping in epoch 27. Best F1: 0.8400
# Fold 249 | Subject RIL_45 | Val F1: 0.8400 | Test F1: 0.9274
# Early stopping in epoch 51. Best F1: 0.8417
# Fold 250 | Subject RIL_46 | Val F1: 0.8417 | Test F1: 0.8182
# Early stopping in epoch 20. Best F1: 0.8396
# Fold 251 | Subject RIL_47 | Val F1: 0.8396 | Test F1: 0.9261
# Early stopping in epoch 31. Best F1: 0.8373
# Fold 252 | Subject RIL_48 | Val F1: 0.8373 | Test F1: 0.9180
# Early stopping in epoch 29. Best F1: 0.8333
# Fold 253 | Subject RIL_49 | Val F1: 0.8333 | Test F1: 0.5373
# Early stopping in epoch 12. Best F1: 0.8310
# Fold 254 | Subject RIL_5 | Val F1: 0.8310 | Test F1: 0.9320
# Early stopping in epoch 26. Best F1: 0.8326
# Fold 255 | Subject RIL_50 | Val F1: 0.8326 | Test F1: 0.8376
# Early stopping in epoch 17. Best F1: 0.8331
# Fold 256 | Subject RIL_51 | Val F1: 0.8331 | Test F1: 0.9175
# Early stopping in epoch 22. Best F1: 0.8332
# Fold 257 | Subject RIL_6 | Val F1: 0.8332 | Test F1: 0.9494
# Early stopping in epoch 26. Best F1: 0.8335
# Fold 258 | Subject RIL_7 | Val F1: 0.8335 | Test F1: 0.8827
# Early stopping in epoch 43. Best F1: 0.8306
# Fold 259 | Subject RIL_8 | Val F1: 0.8306 | Test F1: 0.9477
# Early stopping in epoch 20. Best F1: 0.8361
# Fold 260 | Subject RIL_9 | Val F1: 0.8361 | Test F1: 0.7827
#
# Mean Test F1: 0.8564 ± 0.1209

# %% [markdown]
# ## Analysis

# %%
f1_scores = np.vstack((np.unique(subjects), results_list))
f1_scores = pd.DataFrame(f1_scores.T, columns=['patient', 'score'])
f1_scores.head()
# Out:
#   patient               score
# 0   ACL_1  0.9121704270396128
# 1  ACL_10  0.8442616405639872
# 2  ACL_11  0.9334131373830982
# 3   ACL_2  0.8959575701584045
# 4   ACL_3   0.866689531901126

# %%
f1_scores.to_csv("../results/results_raw_LB_gait_cnnbilstm.csv", index=False)

# %%
results_raw_LB = pd.read_csv("../results/results_raw_LB_gait_cnnbilstm.csv")

# %%
print(f'Mean f1-score: {np.mean(results_raw_LB["score"])}')
print(f'Standard deviation: {np.std(results_raw_LB["score"])}')
# Out:
# Mean f1-score: 0.8564204532107519
# Standard deviation: 0.12092428229275992

# %%
healthy = 'lightgreen'
ortho = 'lightcoral'
neuro = 'lightblue'

cohorts = {
    'HS': (("healthy", healthy), []),
    'ACL': (("ortho", ortho), []),
    'HOA': (("ortho", ortho), []),
    'KOA': (("ortho", ortho), []),
    'CIPN': (("neuro", neuro), []),
    'CVA': (("neuro", neuro), []),
    'PD': (("neuro", neuro), []),
    'RIL': (("neuro", neuro), [])}


for cohort in cohorts.keys():
    for patient_name in results_raw_LB['patient']:
        if cohort in patient_name:
            score = results_raw_LB.loc[results_raw_LB['patient'] == patient_name, 'score'].values[0]
            cohorts[cohort][1].append(score)

mean = np.mean(results_raw_LB["score"])

plt.figure(figsize=(12,8))

for cohort in cohorts.keys():
    bar = plt.bar(
        cohort,
        np.mean(cohorts[cohort][1]),
        yerr=np.std(cohorts[cohort][1]),
        capsize=5,
        label=cohorts[cohort][0][0],
        color=cohorts[cohort][0][1])

    plt.bar_label(bar, fmt='%.4f')

plt.axhline(y=mean, color='black', linestyle='--', label=f'Mean = {mean:.4f}')

plt.ylim(0.4, 1.05)

plt.legend()
plt.show()

# %% [markdown]
# # Prediction Visualization

# %%
best_subj_idx = np.argmax(results_raw_LB['score'])
best_subj = results_raw_LB.iloc[best_subj_idx]['patient'] 
print('Subject with the best score:')
print(results_raw_LB.iloc[best_subj_idx])
print('')

worst_subj_idx = np.argmin(results_raw_LB['score'])
worst_subj = results_raw_LB.iloc[worst_subj_idx]['patient'] 
print('Subject with the worst score:')
print(results_raw_LB.iloc[worst_subj_idx])
print('')
# Out:
# Subject with the best score:
# patient    CIPN_11
# score       0.9678
# Name: 13, dtype: object
#
# Subject with the worst score:
# patient      RIL_17
# score      0.271672
# Name: 217, dtype: object

# %%
best_subj_trial = f"{best_subj}_1"  # Obtain first trial of the best classified subject 
worst_subj_trial = f"{worst_subj}_1"  # Obtain first trial of the worst classified subject 

print(best_subj_trial)
print(worst_subj_trial)
# Out:
# CIPN_11_1
# RIL_17_1

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = best_subj_trial,   
    subject     = best_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"], 
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.9754

# %%
best_subj_meta = load_trial(base_path, best_subj_trial)
best_subj_meta = best_subj_meta["metadata"] 
best_subj_cohort = best_subj_meta["pathologyKey"] 
best_subj_group = best_subj_meta["group"] 

worst_subj_meta = load_trial(base_path, worst_subj_trial)
worst_subj_meta = worst_subj_meta["metadata"] 
worst_subj_cohort = worst_subj_meta["pathologyKey"] 
worst_subj_group = worst_subj_meta["group"]

# %%
path = base_path + f"/{best_subj_group}/{best_subj_cohort}/{best_subj}/{best_subj_trial}"

plot_gait_detection(
    y_true, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = worst_subj_trial,   
    subject     = worst_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"],
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.2692

# %%
path = base_path + f"/{worst_subj_group}/{worst_subj_cohort}/{worst_subj}/{worst_subj_trial}"

plot_gait_detection(
    y_true, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %% [markdown]
# It is clear that there is a big difference in the mean value of the best subject's trial and the worst one's. This might be the reason why this trial is predicted so poorly. In order to try to solve this we're going to apply a different normalization, instead of a global normalization (using just the trining data to avoid data leakage), we're going to normalize per window, that way discrepancies between the mean value for different subjects gets minimized.

# %% [markdown]
# # Only Back Sensor (raw + normalization per window)

# %% [markdown]
# ## Training

# %%
X, y, subjects = load_dataset_gait(base_path, process="raw", sensors=["LB"], window_size=200, stride=50)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
models_per_subject, results_list = train_model_cv(X, y, subjects, model_name="cnnbilstm", norm="window", epochs=100, lr=0.0003, patience=10, out_dir="../checkpoints/CNNBiLSTM/raw_only_back_window_norm")
# Out:
# Early stopping in epoch 31. Best F1: 0.8859
# Fold 1 | Subject ACL_1 | Val F1: 0.8859 | Test F1: 0.8993
# Early stopping in epoch 37. Best F1: 0.8894
# Fold 2 | Subject ACL_10 | Val F1: 0.8894 | Test F1: 0.9485
# Early stopping in epoch 29. Best F1: 0.8851
# Fold 3 | Subject ACL_11 | Val F1: 0.8851 | Test F1: 0.9518
# Early stopping in epoch 42. Best F1: 0.8839
# Fold 4 | Subject ACL_2 | Val F1: 0.8839 | Test F1: 0.8708
# Fold 221 | Subject RIL_2 | Val F1: 0.8586 | Test F1: 0.5085
# Early stopping in epoch 36. Best F1: 0.8550
# Fold 222 | Subject RIL_20 | Val F1: 0.8550 | Test F1: 0.9552
# Early stopping in epoch 30. Best F1: 0.8554
# Fold 223 | Subject RIL_21 | Val F1: 0.8554 | Test F1: 0.8742
# Early stopping in epoch 35. Best F1: 0.8516
# Fold 224 | Subject RIL_22 | Val F1: 0.8516 | Test F1: 0.5298
# Early stopping in epoch 28. Best F1: 0.8564
# Fold 225 | Subject RIL_23 | Val F1: 0.8564 | Test F1: 0.9184
# Early stopping in epoch 17. Best F1: 0.8496
# Fold 226 | Subject RIL_24 | Val F1: 0.8496 | Test F1: 0.7997
# Early stopping in epoch 21. Best F1: 0.8587
# Fold 227 | Subject RIL_25 | Val F1: 0.8587 | Test F1: 0.7433
# Early stopping in epoch 33. Best F1: 0.8555
# Fold 228 | Subject RIL_26 | Val F1: 0.8555 | Test F1: 0.8250
# Early stopping in epoch 24. Best F1: 0.8473
# Fold 229 | Subject RIL_27 | Val F1: 0.8473 | Test F1: 0.9189
# Early stopping in epoch 42. Best F1: 0.8502
# Fold 230 | Subject RIL_28 | Val F1: 0.8502 | Test F1: 0.8897
# Early stopping in epoch 22. Best F1: 0.8600
# Fold 231 | Subject RIL_29 | Val F1: 0.8600 | Test F1: 0.8036
# Early stopping in epoch 16. Best F1: 0.8582
# Fold 232 | Subject RIL_3 | Val F1: 0.8582 | Test F1: 0.8939
# Early stopping in epoch 18. Best F1: 0.8596
# Fold 233 | Subject RIL_30 | Val F1: 0.8596 | Test F1: 0.9441
# Early stopping in epoch 21. Best F1: 0.8590
# Fold 234 | Subject RIL_31 | Val F1: 0.8590 | Test F1: 0.7885
# Early stopping in epoch 21. Best F1: 0.8624
# Fold 235 | Subject RIL_32 | Val F1: 0.8624 | Test F1: 0.7139
# Early stopping in epoch 26. Best F1: 0.8622
# Fold 236 | Subject RIL_33 | Val F1: 0.8622 | Test F1: 0.9358
# Early stopping in epoch 26. Best F1: 0.8597
# Fold 237 | Subject RIL_34 | Val F1: 0.8597 | Test F1: 0.9574
# Early stopping in epoch 25. Best F1: 0.8599
# Fold 238 | Subject RIL_35 | Val F1: 0.8599 | Test F1: 0.9210
# Early stopping in epoch 21. Best F1: 0.8612
# Fold 239 | Subject RIL_36 | Val F1: 0.8612 | Test F1: 0.9585
# Early stopping in epoch 29. Best F1: 0.8584
# Fold 240 | Subject RIL_37 | Val F1: 0.8584 | Test F1: 0.8224
# Early stopping in epoch 16. Best F1: 0.8650
# Fold 241 | Subject RIL_38 | Val F1: 0.8650 | Test F1: 0.8909
# Early stopping in epoch 25. Best F1: 0.8641
# Fold 242 | Subject RIL_39 | Val F1: 0.8641 | Test F1: 0.8804
# Early stopping in epoch 20. Best F1: 0.8596
# Fold 243 | Subject RIL_4 | Val F1: 0.8596 | Test F1: 0.8716
# Early stopping in epoch 22. Best F1: 0.8687
# Fold 244 | Subject RIL_40 | Val F1: 0.8687 | Test F1: 0.9408
# Early stopping in epoch 23. Best F1: 0.8618
# Fold 245 | Subject RIL_41 | Val F1: 0.8618 | Test F1: 0.9225
# Early stopping in epoch 31. Best F1: 0.8594
# Fold 246 | Subject RIL_42 | Val F1: 0.8594 | Test F1: 0.3944
# Early stopping in epoch 20. Best F1: 0.8601
# Fold 247 | Subject RIL_43 | Val F1: 0.8601 | Test F1: 0.8195
# Early stopping in epoch 17. Best F1: 0.8602
# Fold 248 | Subject RIL_44 | Val F1: 0.8602 | Test F1: 0.9185
# Early stopping in epoch 29. Best F1: 0.8595
# Fold 249 | Subject RIL_45 | Val F1: 0.8595 | Test F1: 0.9257
# Early stopping in epoch 19. Best F1: 0.8641
# Fold 250 | Subject RIL_46 | Val F1: 0.8641 | Test F1: 0.8719
# Early stopping in epoch 22. Best F1: 0.8596
# Fold 251 | Subject RIL_47 | Val F1: 0.8596 | Test F1: 0.9354
# Early stopping in epoch 19. Best F1: 0.8574
# Fold 252 | Subject RIL_48 | Val F1: 0.8574 | Test F1: 0.9333
# Early stopping in epoch 30. Best F1: 0.8593
# Fold 253 | Subject RIL_49 | Val F1: 0.8593 | Test F1: 0.5263
# Early stopping in epoch 23. Best F1: 0.8578
# Fold 254 | Subject RIL_5 | Val F1: 0.8578 | Test F1: 0.9376
# Early stopping in epoch 19. Best F1: 0.8593
# Fold 255 | Subject RIL_50 | Val F1: 0.8593 | Test F1: 0.8245
# Early stopping in epoch 19. Best F1: 0.8561
# Fold 256 | Subject RIL_51 | Val F1: 0.8561 | Test F1: 0.9265
# Early stopping in epoch 23. Best F1: 0.8597
# Fold 257 | Subject RIL_6 | Val F1: 0.8597 | Test F1: 0.9594
# Early stopping in epoch 29. Best F1: 0.8583
# Fold 258 | Subject RIL_7 | Val F1: 0.8583 | Test F1: 0.8871
# Early stopping in epoch 22. Best F1: 0.8587
# Fold 259 | Subject RIL_8 | Val F1: 0.8587 | Test F1: 0.9580
# Early stopping in epoch 15. Best F1: 0.8557
# Fold 260 | Subject RIL_9 | Val F1: 0.8557 | Test F1: 0.7842
#
# Mean Test F1: 0.8621 ± 0.1176

# %% [markdown]
# ## Analysis

# %%
f1_scores = np.vstack((np.unique(subjects), results_list))
f1_scores = pd.DataFrame(f1_scores.T, columns=['patient', 'score'])
f1_scores.head()
# Out:
#   patient               score
# 0   ACL_1  0.8992613463903241
# 1  ACL_10  0.9485152527141171
# 2  ACL_11  0.9518007853240557
# 3   ACL_2  0.8708309840613383
# 4   ACL_3  0.9191957750667704

# %%
f1_scores.to_csv("../results/results_raw_LB_gait_cnnbilstm_window_norm.csv", index=False)

# %%
results_raw_LB_win_norm = pd.read_csv("../results/results_raw_LB_gait_cnnbilstm_window_norm.csv")

# %%
print(f'Mean f1-score: {np.mean(results_raw_LB_win_norm["score"])}')
print(f'Standard deviation: {np.std(results_raw_LB_win_norm["score"])}')
# Out:
# Mean f1-score: 0.8621497190978729
# Standard deviation: 0.11760547293897108

# %%
healthy = 'lightgreen'
ortho = 'lightcoral'
neuro = 'lightblue'

cohorts = {
    'HS': (("healthy", healthy), []),
    'ACL': (("ortho", ortho), []),
    'HOA': (("ortho", ortho), []),
    'KOA': (("ortho", ortho), []),
    'CIPN': (("neuro", neuro), []),
    'CVA': (("neuro", neuro), []),
    'PD': (("neuro", neuro), []),
    'RIL': (("neuro", neuro), [])}


for cohort in cohorts.keys():
    for patient_name in results_raw_LB_win_norm['patient']:
        if cohort in patient_name:
            score = results_raw_LB_win_norm.loc[results_raw_LB_win_norm['patient'] == patient_name, 'score'].values[0]
            cohorts[cohort][1].append(score)

mean = np.mean(results_raw_LB_win_norm["score"])

plt.figure(figsize=(12,8))

for cohort in cohorts.keys():
    bar = plt.bar(
        cohort,
        np.mean(cohorts[cohort][1]),
        yerr=np.std(cohorts[cohort][1]),
        capsize=5,
        label=cohorts[cohort][0][0],
        color=cohorts[cohort][0][1])

    plt.bar_label(bar, fmt='%.4f')

plt.axhline(y=mean, color='black', linestyle='--', label=f'Mean = {mean:.4f}')

plt.ylim(0.4, 1.05)

plt.legend()
plt.show()

# %% [markdown]
# # Prediction Visualization

# %%
best_subj_idx = np.argmax(results_raw_LB_win_norm['score'])
best_subj = results_raw_LB_win_norm.iloc[best_subj_idx]['patient'] 
print('Subject with the best score:')
print(results_raw_LB_win_norm.iloc[best_subj_idx])
print('')

worst_subj_idx = np.argmin(results_raw_LB_win_norm['score'])
worst_subj = results_raw_LB_win_norm.iloc[worst_subj_idx]['patient'] 
print('Subject with the worst score:')
print(results_raw_LB_win_norm.iloc[worst_subj_idx])
print('')
# Out:
# Subject with the best score:
# patient       HS_17
# score      0.961907
# Name: 102, dtype: object
#
# Subject with the worst score:
# patient      RIL_17
# score      0.267592
# Name: 217, dtype: object

# %%
best_subj_trial = f"{best_subj}_1"  # Obtain first trial of the best classified subject 
worst_subj_trial = f"{worst_subj}_1"  # Obtain first trial of the worst classified subject 

print(best_subj_trial)
print(worst_subj_trial)
# Out:
# HS_17_1
# RIL_17_1

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = best_subj_trial,   
    subject     = best_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"], 
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back_window_norm"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.9772

# %%
best_subj_meta = load_trial(base_path, best_subj_trial)
best_subj_meta = best_subj_meta["metadata"] 
best_subj_cohort = best_subj_meta["pathologyKey"] 
best_subj_group = best_subj_meta["group"] 

worst_subj_meta = load_trial(base_path, worst_subj_trial)
worst_subj_meta = worst_subj_meta["metadata"] 
worst_subj_cohort = worst_subj_meta["pathologyKey"] 
worst_subj_group = worst_subj_meta["group"]

# %%
path = base_path + f"/{best_subj_group}/{best_subj_cohort}/{best_subj}/{best_subj_trial}"

plot_gait_detection(
    y_true, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = worst_subj_trial,   
    subject     = worst_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB"],
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_only_back_window_norm"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
# Out:
# F1: 0.2662

# %%
path = base_path + f"/{worst_subj_group}/{worst_subj_cohort}/{worst_subj}/{worst_subj_trial}"

plot_gait_detection(
    y_true, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %% [markdown]
# After applying window normalization, the mean F1 score increased from 0.853 to 0.863. However, the worst subject still shows a very low F1 score (around 0.28).
#
# Visual inspection of the predictions reveals that the model correctly detects the timing of gait events. When a gait event occurs, the prediction aligns closely with the ground truth. However, the model frequently confuses the left and right classes. In other words, left events are often predicted as right events and vice versa, while the no-event class is predicted correctly.
#
# This suggests that the model is capable of detecting the presence of a step but struggles to determine which foot generated the event. This is a common issue that comes from the fact just the lower back sensor is being used. With just this sensor we successfully detect steps but we lack the laterality informaion that would help to correctly classify the most difficult examples.

# %% [markdown]
# # Back + Right Foot Sensor (raw)

# %% [markdown]
# ## Training

# %%
X, y, subjects = load_dataset_gait(base_path, process="raw", sensors=["LB", "RF"], window_size=200, stride=50)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
models_per_subject, results_list = train_model_cv(X, y, subjects, model_name="cnnbilstm", norm="window", epochs=100, lr=0.0003, patience=10, out_dir="../checkpoints/CNNBiLSTM/raw_LB_RF")

# %% [markdown]
# ## Analysis

# %%
f1_scores = np.vstack((np.unique(subjects), results_list))
f1_scores = pd.DataFrame(f1_scores.T, columns=['patient', 'score'])
f1_scores.head()

# %%
f1_scores.to_csv("../results/results_raw_LB_RF.csv", index=False)

# %%
results_raw_LB_RF = pd.read_csv("../results/results_raw_LB_RF.csv")

# %%
print(f'Mean f1-score: {np.mean(results_raw_LB_RF["score"])}')
print(f'Standard deviation: {np.std(results_raw_LB_RF["score"])}')

# %%
healthy = 'lightgreen'
ortho = 'lightcoral'
neuro = 'lightblue'

cohorts = {
    'HS': (("healthy", healthy), []),
    'ACL': (("ortho", ortho), []),
    'HOA': (("ortho", ortho), []),
    'KOA': (("ortho", ortho), []),
    'CIPN': (("neuro", neuro), []),
    'CVA': (("neuro", neuro), []),
    'PD': (("neuro", neuro), []),
    'RIL': (("neuro", neuro), [])}


for cohort in cohorts.keys():
    for patient_name in results_raw_LB_RF['patient']:
        if cohort in patient_name:
            score = results_raw_LB_RF.loc[results_raw_LB_RF['patient'] == patient_name, 'score'].values[0]
            cohorts[cohort][1].append(score)

mean = np.mean(results_raw_LB_RF["score"])

plt.figure(figsize=(12,8))

for cohort in cohorts.keys():
    bar = plt.bar(
        cohort,
        np.mean(cohorts[cohort][1]),
        yerr=np.std(cohorts[cohort][1]),
        capsize=5,
        label=cohorts[cohort][0][0],
        color=cohorts[cohort][0][1])

    plt.bar_label(bar, fmt='%.4f')

plt.axhline(y=mean, color='black', linestyle='--', label=f'Mean = {mean:.4f}')

plt.ylim(0.4, 1.05)

plt.legend()
plt.show()

# %% [markdown]
# # Prediction Visualization

# %%
best_subj_idx = np.argmax(results_raw_LB_RF['score'])
best_subj = results_raw_LB_RF.iloc[best_subj_idx]['patient'] 
print('Subject with the best score:')
print(results_raw_LB_RF.iloc[best_subj_idx])
print('')

worst_subj_idx = np.argmin(results_raw_LB_RF['score'])
worst_subj = results_raw_LB_RF.iloc[worst_subj_idx]['patient'] 
print('Subject with the worst score:')
print(results_raw_LB_RF.iloc[worst_subj_idx])
print('')

# %%
best_subj_trial = f"{best_subj}_1"  # Obtain first trial of the best classified subject 
worst_subj_trial = f"{worst_subj}_1"  # Obtain first trial of the worst classified subject 

print(best_subj_trial)
print(worst_subj_trial)

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = best_subj_trial,   
    subject     = best_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB", "RF"], 
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_LB_RF"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")

# %%
best_subj_meta = load_trial(base_path, best_subj_trial)
best_subj_meta = best_subj_meta["metadata"] 
best_subj_cohort = best_subj_meta["pathologyKey"] 
best_subj_group = best_subj_meta["group"] 

worst_subj_meta = load_trial(base_path, worst_subj_trial)
worst_subj_meta = worst_subj_meta["metadata"] 
worst_subj_cohort = worst_subj_meta["pathologyKey"] 
worst_subj_group = worst_subj_meta["group"]

# %%
path = base_path + f"/{best_subj_group}/{best_subj_cohort}/{best_subj}/{best_subj_trial}"

plot_gait_detection(
    y_true, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    best_subj_trial, 
    path, 
    title=f'Visualization of gait events for best predicted subject {best_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

# %%
y_pred, y_true, signal = predict_trial(
    base_path   = base_path,
    trial_name  = worst_subj_trial,   
    subject     = worst_subj,
    model_name  = "cnnbilstm",
    process     = "raw",
    sensors     = ["LB", "RF"],
    window_size = 200,
    stride      = 50,
    out_dir     = "../checkpoints/CNNBiLSTM/raw_LB_RF"
)

print(f"F1: {f1_score(y_true, y_pred, average='macro'):.4f}")

# %%
path = base_path + f"/{worst_subj_group}/{worst_subj_cohort}/{worst_subj}/{worst_subj_trial}"

plot_gait_detection(
    y_true, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (GROUND TRUTH)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')

plot_gait_detection(
    y_pred, 
    worst_subj_trial, 
    path, 
    title=f'Visualization of gait events for worst predicted subject {worst_subj} on trial 1 (PREDICTED)', 
    sensor='LB', 
    signal_channel='Acc_Z', 
    process='raw')
